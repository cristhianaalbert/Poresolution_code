# %% [markdown]
# <a href="https://colab.research.google.com/github/cristhianaalbert/Poresolution_code/blob/Machine-learning-models/ML_models_Sulfur_selected_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Initial setup

# %%
# !pip install requests==2.23.0 folium==0.2.1 imgaug==0.2.6 pycaret pandas shap 
from pycaret.utils import enable_colab
enable_colab()

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pycaret.utils import check_metric
from pycaret.regression import *

# %%
def count_alpha_error (a, alpha=0.1):

    '''Calculates the percentage of elements inside a +- alpha range around the true measured value of the ion;
     a = array with final predictions on unseen data;
     alpha = range of error
    '''
    error = a.Sulfurpredicted / a.Sulfur                           #when we are dealing with log scale of ion, the analysis is still in absolute terms;
    count = error[((1-alpha) < error) & (error <(1+alpha))].size
    total = len(error)
    return count/total
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %% [markdown]
# Load dataset

# %%
from google.colab import files
uploaded = files.upload()
import io
#dataset = pd.read_csv(io.StringIO(uploaded['datasetMPKlogSulfur.csv'].decode('utf-8')))
dataset = pd.read_csv(io.StringIO(uploaded['database_Sulfur_sel_1.csv'].decode('utf-8')),sep=',')

dataset.head()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#      <input type="file" id="files-2baad736-2310-4e76-a449-34edc09064aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2baad736-2310-4e76-a449-34edc09064aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving database_Sulfur_sel_1.csv to database_Sulfur_sel_1.csv
#    Index  waterbinder    PC  SCM1  SCM1_type  SCM2  SCM2_type  PC_CaO  PC_MgO  \
# 0      9          0.5  0.53  0.47          3  0.00          0    62.1    1.65
# 1     10          0.5  0.53  0.47          3  0.00          0    62.1    1.65
# 2     19          0.5  0.53  0.38          3  0.09          5    62.1    1.65
# 3     20          0.5  0.53  0.38          3  0.09          5    62.1    1.65
# 4     29          0.5  0.53  0.38          3  0.09          7    62.1    1.65
#
#    PC_K2O  PC_C3A  C1_T  logSulfur  Sulfur
# 0    0.65     9.2  20.0    0.12710     1.3
# 1    0.65     9.2  20.0   -0.08619     0.8
# 2    0.65     9.2  20.0    0.38917     2.5
# 3    0.65     9.2  20.0    0.26717     1.9
# 4    0.65     9.2  20.0    0.08991     1.2

# %% [markdown]
# Visualize data

# %%
## combine these different collections into a list
mixproportion = [dataset.PC, dataset.SCM1, dataset.SCM2]
#mixproportion = [dataset.waterbinder]
sns.set_theme(style="white")

# Create a figure instance
fig = plt.figure()
# Create an axes instance
ax = fig.add_axes([0,0,1,1])
ax.set_ylabel('Mix proportion')
#ax.set_xlabel('Sample name') ['PC', 'SCM1', 'SCM2', 'w/b'] LEARN HOW TO SET THESE AXIS
# Create the boxplot
bp = ax.violinplot(mixproportion)
plt.show()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
## combine these different collections into a list
mixproportion = [10**dataset.logSulfur]
#mixproportion = [dataset.waterbinder]
sns.set_theme(style="white")

# Create a figure instance
fig = plt.figure()
# Create an axes instance
ax = fig.add_axes([0,0,1,1])
ax.set_ylabel('Mix proportion')
#ax.set_xlabel('Sample name') ['PC', 'SCM1', 'SCM2', 'w/b'] LEARN HOW TO SET THESE AXIS
# Create the boxplot
bp = ax.violinplot(mixproportion)
plt.show()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
fig, ax = plt.subplots()
sns.set_theme(style="white")
#sns.set_palette(sns.color_palette('Paired'))
mixproportion = [10**dataset.logSulfur]
sns.histplot(data=mixproportion, binwidth=0.01, log_scale=True,color='r', legend='Sulfur')
#ax1.set_ylim(0, 30)
#plt.setp(ax, xticks=[10,100,1000])
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
display(dataset.shape)
dataset.describe()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# (149, 14)
#             Index  waterbinder          PC        SCM1   SCM1_type  \
# count  149.000000   149.000000  149.000000  149.000000  149.000000
# mean   462.610738     0.499799    0.807584    0.164832    1.342282
# std    293.071219     0.143727    0.246074    0.205764    1.492195
# min      9.000000     0.310000    0.200000    0.000000    0.000000
# 25%    181.000000     0.450000    0.700000    0.000000    0.000000
# 50%    424.000000     0.500000    0.950000    0.050000    1.000000
# 75%    644.000000     0.500000    1.000000    0.300000    2.000000
# max    999.000000     1.300000    1.000000    0.750000    5.000000
#
#              SCM2   SCM2_type      PC_CaO      PC_MgO      PC_K2O      PC_C3A  \
# count  149.000000  149.000000  142.000000  117.000000  126.000000  128.000000
# mean     0.027919    0.489933   63.535634    1.852564    0.597302    6.925703
# std      0.091247    1.343741    3.119169    0.832618    0.371226    2.181633
# min      0.000000    0.000000   44.630000    0.560000    0.020000    2.400000
# 25%      0.000000    0.000000   62.490000    0.880000    0.290000    4.400000
# 50%      0.000000    0.000000   63.920000    1.840000    0.510000    7.000000
# 75%      0.000000    0.000000   64.702500    2.310000    1.045000    8.250000
# max      0.480000    7.000000   69.340000    4.900000    1.200000   11.000000
#
#             C1_T   logSulfur      Sulfur
# count  99.000000  149.000000  149.000000
# mean   23.020202    0.539624   13.592617
# std     9.705857    0.789636   28.506493
# min     5.000000   -1.000000    0.100000
# 25%    20.000000   -0.045760    0.900000
# 50%    20.000000    0.389170    2.500000
# 75%    22.000000    1.230450   17.000000
# max    60.000000    2.437750  274.000000

# %%
SCM = dataset.SCM1 + dataset.SCM2
dataset.insert(dataset.shape[1],'SCM', SCM)
dataset.drop(['SCM1','SCM2','SCM1_type','SCM2_type'],axis=1,inplace=True)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
dataset
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#      Index  waterbinder    PC  PC_CaO  PC_MgO  PC_K2O  PC_C3A  C1_T  \
# 0        9         0.50  0.53   62.10    1.65    0.65    9.20  20.0
# 1       10         0.50  0.53   62.10    1.65    0.65    9.20  20.0
# 2       19         0.50  0.53   62.10    1.65    0.65    9.20  20.0
# 3       20         0.50  0.53   62.10    1.65    0.65    9.20  20.0
# 4       29         0.50  0.53   62.10    1.65    0.65    9.20  20.0
# 5       30         0.50  0.53   62.10    1.65    0.65    9.20  20.0
# 6       39         0.50  0.53   62.10    1.65    0.65    9.20  20.0
# 7       40         0.50  0.53   62.10    1.65    0.65    9.20  20.0
# 8       52         0.60  1.00     NaN     NaN     NaN     NaN  21.0
# 9      153         0.50  1.00   64.20     NaN    0.29    7.00   NaN
# 10     154         0.38  0.75   64.20     NaN    0.29    7.00   NaN
# 11     155         0.40  0.70   64.20     NaN    0.29    7.00   NaN
# 12     156         0.44  0.25   64.20     NaN    0.29    7.00   NaN
# 13     157         0.47  0.90   64.20     NaN    0.29    7.00   NaN
# 14     158         0.50  1.00   64.20     NaN    0.29    7.00   NaN
# 15     159         0.50  1.00     NaN     NaN     NaN    7.00   NaN
# 16     160         0.38  0.75   64.20     NaN    0.29    7.00   NaN
# 17     161         0.40  0.70   64.20     NaN    0.29    7.00   NaN
# 18     162         0.44  0.25   64.20     NaN    0.29    7.00   NaN
# 19     163         0.47  0.90   64.20     NaN    0.29    7.00   NaN
# 20     164         0.50  1.00   64.20     NaN    0.29    7.00   NaN
# 21     165         0.50  1.00     NaN     NaN     NaN    7.00   NaN
# 22     166         0.38  0.75   64.20     NaN    0.29    7.00   NaN
# 23     167         0.40  0.70   64.20     NaN    0.29    7.00   NaN
# 24     168         0.44  0.25   64.20     NaN    0.29    7.00   NaN
# 25     169         0.47  0.90   64.20     NaN    0.29    7.00   NaN
# 26     170         0.50  1.00   64.20     NaN    0.29    7.00   NaN
# 27     171         0.50  1.00     NaN     NaN     NaN    7.00   NaN
# 28     172         0.38  0.75   64.20     NaN    0.29    7.00   NaN
# 29     173         0.40  0.70   64.20     NaN    0.29    7.00   NaN
# 30     174         0.44  0.25   64.20     NaN    0.29    7.00   NaN
# 31     175         0.47  0.90   64.20     NaN    0.29    7.00   NaN
# 32     176         0.50  1.00   64.20     NaN    0.29    7.00   NaN
# 33     177         0.50  1.00     NaN     NaN     NaN    7.00   NaN
# 34     178         0.38  0.75   64.20     NaN    0.29    7.00   NaN
# 35     179         0.40  0.70   64.20     NaN    0.29    7.00   NaN
# 36     180         0.44  0.25   64.20     NaN    0.29    7.00   NaN
# 37     181         0.47  0.90   64.20     NaN    0.29    7.00   NaN
# 38     185         0.50  1.00   67.41    0.81    0.23    4.04  20.0
# 39     187         0.50  1.00   67.41    0.81    0.23    4.04  20.0
# 40     193         0.50  0.60   67.41    0.81    0.23    4.04  20.0
# 41     194         0.50  0.60   67.41    0.81    0.23    4.04  20.0
# 42     196         0.50  0.60   67.41    0.81    0.23    4.04  20.0
# 43     204         0.50  0.38   67.41    0.81    0.23    4.04  20.0
# 44     206         0.50  0.38   67.41    0.81    0.23    4.04  20.0
# 45     208         0.50  0.20   67.41    0.81    0.23    4.04  20.0
# 46     209         0.50  0.20   67.41    0.81    0.23    4.04  20.0
# 47     211         0.50  0.20   67.41    0.81    0.23    4.04  20.0
# 48     213         0.50  1.00   64.87    1.35    0.58   10.43   NaN
# 49     214         0.50  1.00   61.00    4.90    0.91    5.35   NaN
# 50     275         0.50  1.00   60.60    2.90    1.20   11.00  20.0
# 51     276         0.50  1.00   60.60    2.90    1.20   11.00  20.0
# 52     277         0.50  1.00   60.60    2.90    1.20   11.00  20.0
# 53     280         0.50  0.95   60.60    2.90    1.20   11.00  20.0
# 54     281         0.50  0.95   60.60    2.90    1.20   11.00  20.0
# 55     282         0.50  0.95   60.60    2.90    1.20   11.00  20.0
# 56     339         0.50  1.00   62.40    1.84    0.35     NaN  21.0
# 57     341         0.50  1.00   62.40    1.84    0.35     NaN  21.0
# 58     345         0.50  0.60   62.40    1.84    0.35     NaN  21.0
# 59     347         0.50  0.60   62.40    1.84    0.35     NaN  21.0
# 60     349         0.50  0.50   62.40    1.84    0.35     NaN  21.0
# 61     351         0.50  0.50   62.40    1.84    0.35     NaN  21.0
# 62     353         0.50  0.80   62.40    1.84    0.35     NaN  21.0
# 63     355         0.50  0.80   62.40    1.84    0.35     NaN  21.0
# 64     357         0.50  0.35   62.40    1.84    0.35     NaN  21.0
# 65     359         0.50  0.35   62.40    1.84    0.35     NaN  21.0
# 66     361         0.50  0.20   62.40    1.84    0.35     NaN  21.0
# 67     363         0.50  0.20   62.40    1.84    0.35     NaN  21.0
# 68     367         0.50  1.00   63.20    1.90    1.10    7.89  20.0
# 69     368         0.50  1.00   63.20    1.90    1.10    7.89  20.0
# 70     369         0.45  1.00     NaN     NaN     NaN     NaN   NaN
# 71     370         0.45  1.00     NaN     NaN     NaN     NaN   NaN
# 72     411         0.31  1.00   63.60    2.20    1.07    8.25  60.0
# 73     423         0.47  1.00   63.60    2.20    1.07    8.25  60.0
# 74     424         0.47  1.00   63.60    2.20    1.07    8.25  60.0
# 75     425         0.47  1.00   63.60    2.20    1.07    8.25  60.0
# 76     445         0.50  1.00   62.20    2.10    1.00    8.60   NaN
# 77     500         0.50  1.00   63.20    1.85    1.12    7.90  20.0
# 78     501         0.50  1.00   63.20    1.85    1.12    7.90  20.0
# 79     502         0.50  1.00   63.20    1.85    1.12    7.90  20.0
# 80     507         0.40  1.00   65.70    0.85    0.22    3.90  20.0
# 81     508         0.40  1.00   65.70    0.85    0.22    3.90  20.0
# 82     509         1.30  1.00   65.70    0.85    0.22    3.90  20.0
# 83     510         1.30  1.00   65.70    0.85    0.22    3.90  20.0
# 84     511         1.30  1.00   66.40    0.88    0.37    2.40  20.0
# 85     512         1.30  1.00   66.40    0.88    0.37    2.40  20.0
# 86     515         0.40  1.00   65.70    0.85    0.22    3.90   5.0
# 87     516         0.40  1.00   65.70    0.85    0.22    3.90   5.0
# 88     521         0.40  1.00   65.70    0.85    0.22    3.90  20.0
# 89     522         0.40  1.00   65.70    0.85    0.22    3.90  20.0
# 90     526         0.40  1.00   65.70    0.85    0.22    3.90  50.0
# 91     527         0.40  1.00   65.70    0.85    0.22    3.90  50.0
# 92     534         0.40  1.00   63.90    1.80    0.78    7.50  20.0
# 93     535         0.40  1.00   63.90    1.80    0.78    7.50  20.0
# 94     536         0.40  1.00   63.90    1.80    0.78    7.50  20.0
# 95     543         0.40  0.96   63.90    1.80    0.78    7.50  20.0
# 96     544         0.40  0.96   63.90    1.80    0.78    7.50  20.0
# 97     545         0.40  0.96   63.90    1.80    0.78    7.50  20.0
# 98     557         0.45  1.00   65.59    1.91    0.43    8.74  22.0
# 99     558         0.45  1.00   69.34    0.56    0.12    4.52  22.0
# 100    630         0.50  1.00   63.92    2.62    1.18    7.37  22.0
# 101    631         0.50  1.00   63.92    2.62    1.18    7.37  22.0
# 102    632         0.50  1.00   63.92    2.62    1.18    7.37  22.0
# 103    634         0.50  0.90   63.92    2.62    1.18    7.37  22.0
# 104    635         0.50  0.90   63.92    2.62    1.18    7.37  22.0
# 105    636         0.50  0.90   63.92    2.62    1.18    7.37  22.0
# 106    638         0.50  0.90   63.92    2.62    1.18    7.37  22.0
# 107    639         0.50  0.90   63.92    2.62    1.18    7.37  22.0
# 108    640         0.50  0.90   63.92    2.62    1.18    7.37  22.0
# 109    642         0.50  0.80   63.92    2.62    1.18    7.37  22.0
# 110    643         0.50  0.80   63.92    2.62    1.18    7.37  22.0
# 111    644         0.50  0.80   63.92    2.62    1.18    7.37  22.0
# 112    646         0.50  0.70   63.92    2.62    1.18    7.37  22.0
# 113    647         0.50  0.70   63.92    2.62    1.18    7.37  22.0
# 114    648         0.50  0.70   63.92    2.62    1.18    7.37  22.0
# 115    649         0.50  1.00   61.71    2.19    0.92    6.84  20.0
# 116    650         0.50  1.00   61.71    2.19    0.92    6.84  20.0
# 117    651         0.50  1.00   44.63    2.01    1.06     NaN  20.0
# 118    652         0.50  1.00   44.63    2.01    1.06     NaN  20.0
# 119    771         0.50  1.00   68.34    0.59    0.02    5.00  22.0
# 120    821         0.58  1.00   65.90    0.88    0.54    3.71  20.0
# 121    822         0.58  1.00   65.90    0.88    0.54    3.71  20.0
# 122    824         0.58  0.75   65.90    0.88    0.54    3.71  20.0
# 123    825         0.58  0.75   65.90    0.88    0.54    3.71  20.0
# 124    827         0.58  0.50   65.90    0.88    0.54    3.71  20.0
# 125    828         0.58  0.50   65.90    0.88    0.54    3.71  20.0
# 126    830         0.58  0.25   65.90    0.88    0.54    3.71  20.0
# 127    831         0.58  0.25   65.90    0.88    0.54    3.71  20.0
# 128    833         0.58  0.70   65.90    0.88    0.54    3.71  20.0
# 129    834         0.58  0.70   65.90    0.88    0.54    3.71  20.0
# 130    921         0.40  1.00   63.22    4.15    0.51    7.00  30.0
# 131    929         0.40  1.00   63.22    4.15    0.51    7.00  40.0
# 132    939         0.40  1.00   63.22    4.15    0.51    7.00  50.0
# 133    984         0.40  1.00   62.76    2.31     NaN    9.77   NaN
# 134    985         0.45  1.00   62.76    2.31     NaN    9.77   NaN
# 135    986         0.50  1.00   62.76    2.31     NaN    9.77   NaN
# 136    987         0.55  1.00   62.76    2.31     NaN    9.77   NaN
# 137    988         0.40  0.75   62.76    2.31     NaN    9.77   NaN
# 138    989         0.45  0.75   62.76    2.31     NaN    9.77   NaN
# 139    990         0.50  0.75   62.76    2.31     NaN    9.77   NaN
# 140    991         0.55  0.75   62.76    2.31     NaN    9.77   NaN
# 141    992         0.40  0.75   62.76    2.31     NaN    9.77   NaN
# 142    993         0.45  0.75   62.76    2.31     NaN    9.77   NaN
# 143    994         0.50  0.75   62.76    2.31     NaN    9.77   NaN
# 144    995         0.55  0.75   62.76    2.31     NaN    9.77   NaN
# 145    996         0.40  1.00   56.39    2.17     NaN     NaN   NaN
# 146    997         0.45  1.00   56.39    2.17     NaN     NaN   NaN
# 147    998         0.50  1.00   56.39    2.17     NaN     NaN   NaN
# 148    999         0.55  1.00   56.39    2.17     NaN     NaN   NaN
#
#      logSulfur  Sulfur   SCM
# 0      0.12710     1.3  0.47
# 1     -0.08619     0.8  0.47
# 2      0.38917     2.5  0.47
# 3      0.26717     1.9  0.47
# 4      0.08991     1.2  0.47
# 5      0.01703     1.0  0.47
# 6      0.39794     2.5  0.47
# 7      0.25527     1.8  0.47
# 8      0.39759     2.5  0.00
# 9      0.20412     1.6  0.00
# 10     0.32222     2.1  0.25
# 11     0.25527     1.8  0.30
# 12     0.25527     1.8  0.75
# 13     0.82607     6.7  0.10
# 14    -0.39794     0.4  0.00
# 15    -0.15490     0.7  0.00
# 16    -0.39794     0.4  0.25
# 17    -0.30103     0.5  0.30
# 18    -0.52288     0.3  0.75
# 19    -1.00000     0.1  0.10
# 20     0.25527     1.8  0.00
# 21     0.34242     2.2  0.00
# 22     0.30103     2.0  0.25
# 23     0.39794     2.5  0.30
# 24     0.27875     1.9  0.75
# 25     0.11394     1.3  0.10
# 26    -0.09691     0.8  0.00
# 27     0.07918     1.2  0.00
# 28    -0.09691     0.8  0.25
# 29    -0.04576     0.9  0.30
# 30     0.14613     1.4  0.75
# 31     0.91908     8.3  0.10
# 32    -0.15490     0.7  0.00
# 33    -0.15490     0.7  0.00
# 34     0.07918     1.2  0.25
# 35    -0.04576     0.9  0.30
# 36     0.30103     2.0  0.75
# 37     0.86332     7.3  0.10
# 38    -0.09691     0.8  0.00
# 39     0.04139     1.1  0.00
# 40    -0.39794     0.4  0.40
# 41    -0.69897     0.2  0.40
# 42    -0.52288     0.3  0.40
# 43    -1.00000     0.1  0.63
# 44    -0.69897     0.2  0.63
# 45    -0.69897     0.2  0.81
# 46    -0.22185     0.6  0.81
# 47    -0.04576     0.9  0.81
# 48     1.18752    15.4  0.00
# 49     1.51851    33.0  0.00
# 50     0.96848     9.3  0.00
# 51     1.03743    10.9  0.00
# 52     1.11394    13.0  0.00
# 53     1.23300    17.1  0.05
# 54     1.39967    25.1  0.05
# 55     1.44091    27.6  0.05
# 56    -0.87531     0.1  0.00
# 57    -0.59336     0.3  0.00
# 58    -0.05618     0.9  0.40
# 59    -0.15322     0.7  0.40
# 60     1.35593    22.7  0.50
# 61     1.05090    11.2  0.50
# 62    -0.48284     0.3  0.20
# 63    -0.46931     0.3  0.20
# 64     0.27755     1.9  0.65
# 65     0.80138     6.3  0.65
# 66     1.50884    32.3  0.80
# 67     1.24278    17.5  0.80
# 68     1.04139    11.0  0.00
# 69     1.23045    17.0  0.00
# 70    -0.31284     0.5  0.00
# 71     0.22964     1.7  0.00
# 72     2.43775   274.0  0.00
# 73     1.90849    81.0  0.00
# 74     2.10037   126.0  0.00
# 75     2.05308   113.0  0.00
# 76     0.91381     8.2  0.00
# 77     1.04139    11.0  0.00
# 78     1.23045    17.0  0.00
# 79     1.20412    16.0  0.00
# 80     0.25527     1.8  0.00
# 81     0.25527     1.8  0.00
# 82    -0.92082     0.1  0.00
# 83    -0.92082     0.1  0.00
# 84    -0.52288     0.3  0.00
# 85    -0.48149     0.3  0.00
# 86    -0.22185     0.6  0.00
# 87    -0.04576     0.9  0.00
# 88     0.07918     1.2  0.00
# 89     0.34242     2.2  0.00
# 90     1.15229    14.2  0.00
# 91     1.12057    13.2  0.00
# 92     1.00000    10.0  0.00
# 93     1.32222    21.0  0.00
# 94     1.34242    22.0  0.00
# 95     1.14613    14.0  0.04
# 96     1.61278    41.0  0.04
# 97     1.53148    34.0  0.04
# 98     0.51014     3.2  0.00
# 99     0.27277     1.9  0.00
# 100    1.49136    31.0  0.00
# 101    1.64345    44.0  0.00
# 102    1.43136    27.0  0.00
# 103    1.50515    32.0  0.10
# 104    1.50515    32.0  0.10
# 105    1.20412    16.0  0.10
# 106    1.60206    40.0  0.10
# 107    1.47712    30.0  0.10
# 108    1.43136    27.0  0.10
# 109    1.51851    33.0  0.20
# 110    1.53148    34.0  0.20
# 111    1.39794    25.0  0.20
# 112    1.54407    35.0  0.30
# 113    1.55630    36.0  0.30
# 114    1.50515    32.0  0.30
# 115    1.04532    11.1  0.00
# 116    0.57978     3.8  0.00
# 117    0.63347     4.3  0.00
# 118    0.20412     1.6  0.00
# 119   -1.00000     0.1  0.00
# 120    0.40129     2.5  0.00
# 121    0.35593     2.3  0.00
# 122    0.05887     1.1  0.25
# 123    0.33969     2.2  0.25
# 124   -0.55116     0.3  0.50
# 125   -0.04301     0.9  0.50
# 126   -0.80643     0.2  0.75
# 127   -0.32931     0.5  0.75
# 128   -0.50540     0.3  0.30
# 129   -0.17634     0.7  0.30
# 130    0.07918     1.2  0.00
# 131    0.38021     2.4  0.00
# 132    0.61278     4.1  0.00
# 133    1.78533    61.0  0.00
# 134    1.51851    33.0  0.00
# 135    1.20412    16.0  0.00
# 136    1.04139    11.0  0.00
# 137    1.56820    37.0  0.25
# 138    1.39794    25.0  0.25
# 139    1.11394    13.0  0.25
# 140    1.04139    11.0  0.25
# 141    1.38021    24.0  0.25
# 142    1.11394    13.0  0.25
# 143    0.77815     6.0  0.25
# 144    0.60206     4.0  0.25
# 145    1.61278    41.0  0.00
# 146    1.27875    19.0  0.00
# 147    1.00000    10.0  0.00
# 148    0.84510     7.0  0.00

# %% [markdown]
# # Modeling

# %%
#defining initial parameters

model_list = ['rf','et']                        #models to be tested;
seed_list = [76,89,140,267,870]                       #seeds for separating data to train/test model and for final predictions; 
sid_list = [22,453,563,914]                         #seeds for session id on setup - I believe it defines how cross-validation groups are defined;
featsel_list = [1.0, 0.4, 0.3,0.2,0.15]         #feature_selection_threshold for setup - defines how many features will be considered in the model (train/test/prediction);
featsel_list = [1.0]         #feature_selection_threshold for setup - defines how many features will be considered in the model (train/test/prediction);
seed_list = [20, 76,89,140,267,310, 560, 771, 870, 952]                       #seeds for separating data to train/test model and for final predictions; 
sid_list = [22,120, 200, 420, 453, 563, 680, 739, 810, 914]                         #seeds for session id on setup - I believe it defines how cross-validation groups are defined;
kfold_list = [5]                            #numbers of folds for cross-validation - I didn't notice differences on the final results;

alpha1=0.1                                   #error range - used to evaluate +-10% error of prediction around the measured value;
alpha2=0.25                                  #error range - used to evaluate +-25% error of prediction around the measured value;
i=0                                          #initial index;

#tunemodel
tune_on = 1   # 1 to avoid tuning of hyperparameteres; 2 to allow tuning of hyperparameteres;
#These parameters are focused on decision tree methods;
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 20, stop = 100, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 10, num = 5)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
tune_params = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
                        

totalsystems = len(model_list)*len(seed_list)*len(sid_list)*len(featsel_list)*len(kfold_list)*tune_on   #total number of systems considering all variables; times 2 because we have tuned models
totalcolumns = 10                                                                                 #depends on the statistic variables stored on the array "summary" (modelname, ..., R2, RMSE, alpha, etc)
summary = np.zeros((totalsystems, totalcolumns),dtype=object)                                     #array summary mentioned above;

#REMEMBER TO ALTER DEPENDING ON THE SIZE OF DATASET (HOW MANY VARIABLES IT HAS)
estimativefeat = round(int(2*dataset.shape[1]))                        #depends on the number of features in dataset - needs to be a little bit bigger to account for categorical features that are transformed (one hot encoding method)
mostimpfeat = 4                           #number of most important features to be analysed; 15 or 10 seems a reasonable number;


mostimpfeat_value = np.ndarray(shape=(totalsystems, mostimpfeat+1),dtype=object)                      #arrays to store most important features properties; plus 1 is for indexing modelname
mostimpfeat_name = np.zeros(shape=(totalsystems, mostimpfeat+1),dtype=object)
mostimpfeat_test = np.zeros(shape=(totalsystems, 2*mostimpfeat+1),dtype=object)

feat_summary=[]

mostimpfeat_value_full = np.zeros(shape=(totalsystems, estimativefeat),dtype=float)               #arrays to store all features properties
mostimpfeat_name_full = np.zeros(shape=(totalsystems, estimativefeat),dtype=object)
mostimpfeat_full_summary = []


#numfeat = ['SCM2_Amorphous','C1_T','C2_Age_days','C2_T','Pressure_MPa']
ignfeat = ['Index',"Sulfur"]
numfeat = ['waterbinder','aggregatesbinder',
           'PC','SCM1','SCM2','PC_CaO','PC_SiO2','PC_Al2O3', 'PC_Fe2O3', 'PC_SO3', 'PC_MgO', 'PC_Na2O', 'PC_K2O', 
           'PC_TiO2', 'PC_P2O5', 'PC_MnO', 'PC_CO2','PC_LOI', 'PC_Amorphous', 'PC_C3S', 'PC_C2S', 'PC_C3A', 'PC_C4AF','PC_Blaine','PC_BET',
           'SCM1_CaO',	'SCM1_SiO2',	'SCM1_Al2O3',	'SCM1_Fe2O3',	'SCM1_SO3',	'SCM1_MgO',	'SCM1_Na2O',	'SCM1_K2O',	
           'SCM1_TiO2',	'SCM1_P2O5',	'SCM1_MnO',	'SCM1_CO2',	'SCM1_LOI','SCM1_Amorphous','SCM1_Blaine','SCM1_BET',
           'SCM2_CaO',	'SCM2_SiO2',	'SCM2_Al2O3',	'SCM2_Fe2O3',	'SCM2_SO3',	'SCM2_MgO',	'SCM2_Na2O',	'SCM2_K2O',	
           'SCM2_TiO2',	'SCM2_P2O5',	'SCM2_MnO',	'SCM2_CO2',	'SCM2_LOI','SCM2_Amorphous','SCM2_Blaine','SCM2_BET',
           'C1_Age_days','C1_RH','C1_T','C2_Age_days','C2_RH','C2_T','Final_age_days','Pressure_MPa']

numfeat = ['waterbinder','PC','SCM','PC_CaO','PC_MgO', 'PC_K2O','PC_C3A','C1_T']


for modelname in model_list:                                #running for different models at same loop;
  for p in range(tune_on):                                                                                          #creating a normal and tuned version of the model  %TO AVOID HAVING TUNED MODELS, JUST PUT THE RANGE TO 1 INSTEAD OF 2

    for seed in seed_list:                                                                                      #running for different initial seeds for ramdom state - separation of data to train/test model and for final predictions;
      data = dataset.sample(frac=0.85, random_state=seed)
      data_unseen = dataset.drop(data.index)
      data.reset_index(drop=True, inplace=True)
      data_unseen.reset_index(drop=True, inplace=True)

      for sid in sid_list:                                                                                      #running for different seeds for session id on setup - I believe it defines how cross-validation groups are defined;
        for featsel in featsel_list:                                                                            #running different feature_selection_threshold for setup - defines how many features will be considered in the model (train/test/prediction)

          exp_ps = setup(data = data, target = 'logSulfur', session_id=sid, normalize = True, 
                        combine_rare_levels = True, rare_level_threshold = 0.05,
                        remove_outliers = True, log_experiment = True, experiment_name = 'poresolution',
                        numeric_features = numfeat, fold=5, ignore_features = ignfeat,
                        feature_selection = True, silent=True, verbose=False)

          for kfold in kfold_list:                          #running for different numbers of folds for cross-validation - I didn't notice differences on the final results;
            #model = create_model(modelname,fold=kfold, n_estimators=80,max_depth=10, verbose=False)
            model = create_model(modelname,n_estimators=80,max_depth=8,fold=kfold,verbose=False)


            if p == 0:                                      #normal model
              model = model           
              modelnameb = modelname

            if p == 1:                                      #tuned model
              model = tune_model(model,fold=kfold, optimize="RMSE", verbose=False)
              modelnameb = 'tuned_'+str(modelname)
            
            aaa=get_logs()

            final_model = finalize_model(model)
            unseen_predictions = predict_model(final_model, data=data_unseen, round=None)
            #test_predictions = predict_model(final_model, data=data_testprediction, round=None)

            #checking accuracy of predictions on unseen data - R2, RMSE, fraction of predictions within alpha error range;
            a = unseen_predictions
            alinear = pd.DataFrame([np.array(10**a.logSulfur), np.array(10**a.Label)]).T
            alinear.columns=["Sulfur","Sulfurpredicted"]            
            R2 = check_metric(alinear.Sulfur, alinear.Sulfurpredicted, 'R2' )     
            RMSE = check_metric(alinear.Sulfur, alinear.Sulfurpredicted, 'RMSE' )
            erroralpha1 = count_alpha_error(alinear, alpha1)
            erroralpha2 = count_alpha_error(alinear, alpha2)

            nfeat = get_config('X_train').shape[1]           #number of features considered by model - depends on feature_selection_threshold;               

            summary[i,:] = ([modelnameb, seed, sid, kfold, featsel,nfeat, R2, RMSE, erroralpha1, erroralpha2])     #storing all these metrics for each system;


            featimp = pd.DataFrame({'Feature': get_config('X_train').columns, 'Value' : abs(final_model.feature_importances_)})    #getting the feature importance scores for all systems;
            featimpsort = featimp.sort_values(by='Value', ascending=False)[:mostimpfeat]                                           #organizing feature importance scores in descending order of importance;
            
            feat1 = np.array(featimpsort)[0,0]            #1st to 5th most important feature -> to be displayed during evaluations -> important to checks during runs;
            feat2 = np.array(featimpsort)[1,0]
            feat3 = np.array(featimpsort)[2,0]
            feat4 = np.array(featimpsort)[3,0]
            #feat5 = np.array(featimpsort)[4,0]

            mostimpfeat_name[i][0] = modelnameb                                                      #indexing the modelnameb to later identify where did the features get the most contribution
            mostimpfeat_value[i][0] = modelnameb                                                     #indexing the modelnameb to later identify where did the features get the most contribution
            for j in range(mostimpfeat):                                                             #arranging names and values of most important features in two arrays; 
              mostimpfeat_name[i][j+1] = np.array(featimpsort)[j,0]                                  #feature name
              mostimpfeat_value[i][j+1] = np.array(featimpsort)[j,1]/np.array(featimpsort)[0,1]      #feature importance value normalized in relation to most important feature;

            mostimpfeat_test[i][0] = modelnameb                                                      #indexing the modelnameb to later identify where did the features get the most contribution
            for j in range(mostimpfeat):                                                             #arranging names and values of most important features in one array; -> best method;
              mostimpfeat_test[i][2*j+1] = np.array(featimpsort)[j,0]                                #feature name
              mostimpfeat_test[i][2*j+2] = np.array(featimpsort)[j,1]/np.array(featimpsort)[0,1]     #feature importance value normalized in relation to most important feature;


            for k in range(nfeat):                                                                   #arranging names and values of all features in two arrays; 
              mostimpfeat_name_full[i][k] = np.array(featimp)[k,0]                                   #feature name
              mostimpfeat_value_full[i][k] = np.array(featimp)[k,1]/np.array(featimpsort)[0,1]       #feature importance value normalized in relation to most important feature;


            
            for ida, system in enumerate(mostimpfeat_name_full):          #arranging names and values of most important features in one array; -> best method;
              for idb, name in enumerate(system):
                value = mostimpfeat_value_full[ida][idb]
                mostimpfeat_full_summary.append([ida,idb,name,value])      

            i=i+1                                                         #finishing round and going to next one; increasing index number accordingly;

        #print('random_state=',seed,'  session_id=',sid,'  kfold=',kfold,'  R2=', R2, '  RMSE=', RMSE)
            print('''model = {: <10}  random_state = {: <5}  sid = {: <5}  feat_sel_thresh = {: <5}  features = {:<5}  R2 = {:.3f}   RMSE = {:.3f}  Error_a1 = {:.3f}   Error_a2 = {:.3f}   Feat1 = {: <10}   Feat2 = {: <10}   Feat3 = {: <10}     Feat4 = {: <10}  '''
                    .format(modelnameb,seed,sid,featsel, nfeat, R2, RMSE,erroralpha1, erroralpha2, feat1, feat2, feat3, feat4))


pd.DataFrame(mostimpfeat_test).to_csv('mostimpfeat_test.csv',index=False)

table_summary = pd.DataFrame(summary)                 #creating table of statistics for all systems;
table_summary.columns = ['model','random_state','sid','kfold','feat_sel_thresh','features','R2','RMSE','Error_alpha_0.1','Error_alpha_0.25']


columnname = []                                       #creating column names for most important features - we might change the number of selected features 
for i in range(mostimpfeat):
  columnname.append(str(i+1)+'N')
  columnname.append(str(i+1)+'V')

table_mostimpfeat = pd.DataFrame(mostimpfeat_test[:,1:])    #creating table of most important features with their name and value/score;
table_mostimpfeat.columns = columnname

finaltable = pd.concat([table_summary, table_mostimpfeat], axis=1, join='inner')   #combining statistics and most imp features in only one table; it helps on converting it to only one csv file later.
finaltable.to_csv('finaltable.csv')
display(finaltable)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# model = rf          random_state = 20     sid = 22     feat_sel_thresh = 1.0    features = 6      R2 = 0.884   RMSE = 8.605  Error_a1 = 0.045   Error_a2 = 0.136   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = rf          random_state = 20     sid = 120    feat_sel_thresh = 1.0    features = 6      R2 = 0.894   RMSE = 8.211  Error_a1 = 0.045   Error_a2 = 0.136   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_CaO         Feat4 = PC
# model = rf          random_state = 20     sid = 200    feat_sel_thresh = 1.0    features = 6      R2 = 0.902   RMSE = 7.922  Error_a1 = 0.045   Error_a2 = 0.136   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_CaO         Feat4 = SCM
# model = rf          random_state = 20     sid = 420    feat_sel_thresh = 1.0    features = 7      R2 = 0.942   RMSE = 6.086  Error_a1 = 0.091   Error_a2 = 0.136   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = rf          random_state = 20     sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.888   RMSE = 8.453  Error_a1 = 0.000   Error_a2 = 0.136   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_CaO         Feat4 = SCM
# model = rf          random_state = 20     sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.837   RMSE = 10.196  Error_a1 = 0.000   Error_a2 = 0.136   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = SCM
# model = rf          random_state = 20     sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.911   RMSE = 7.553  Error_a1 = 0.000   Error_a2 = 0.136   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_CaO         Feat4 = SCM
# model = rf          random_state = 20     sid = 739    feat_sel_thresh = 1.0    features = 6      R2 = 0.903   RMSE = 7.851  Error_a1 = 0.000   Error_a2 = 0.182   Feat1 = PC_K2O       Feat2 = PC_CaO       Feat3 = SCM            Feat4 = PC_MgO
# model = rf          random_state = 20     sid = 810    feat_sel_thresh = 1.0    features = 6      R2 = 0.898   RMSE = 8.057  Error_a1 = 0.000   Error_a2 = 0.227   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_CaO
# model = rf          random_state = 20     sid = 914    feat_sel_thresh = 1.0    features = 6      R2 = 0.911   RMSE = 7.540  Error_a1 = 0.136   Error_a2 = 0.182   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_CaO
# model = rf          random_state = 76     sid = 22     feat_sel_thresh = 1.0    features = 7      R2 = 0.957   RMSE = 2.121  Error_a1 = 0.136   Error_a2 = 0.364   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = SCM
# model = rf          random_state = 76     sid = 120    feat_sel_thresh = 1.0    features = 6      R2 = 0.940   RMSE = 2.506  Error_a1 = 0.182   Error_a2 = 0.318   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_CaO         Feat4 = PC_C3A
# model = rf          random_state = 76     sid = 200    feat_sel_thresh = 1.0    features = 7      R2 = 0.941   RMSE = 2.480  Error_a1 = 0.091   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = rf          random_state = 76     sid = 420    feat_sel_thresh = 1.0    features = 6      R2 = 0.945   RMSE = 2.397  Error_a1 = 0.227   Error_a2 = 0.364   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 76     sid = 453    feat_sel_thresh = 1.0    features = 7      R2 = 0.953   RMSE = 2.219  Error_a1 = 0.182   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = rf          random_state = 76     sid = 563    feat_sel_thresh = 1.0    features = 6      R2 = 0.923   RMSE = 2.835  Error_a1 = 0.091   Error_a2 = 0.364   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = SCM
# model = rf          random_state = 76     sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.947   RMSE = 2.365  Error_a1 = 0.091   Error_a2 = 0.455   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC
# model = rf          random_state = 76     sid = 739    feat_sel_thresh = 1.0    features = 6      R2 = 0.921   RMSE = 2.873  Error_a1 = 0.136   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = SCM
# model = rf          random_state = 76     sid = 810    feat_sel_thresh = 1.0    features = 7      R2 = 0.952   RMSE = 2.236  Error_a1 = 0.091   Error_a2 = 0.455   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = SCM
# model = rf          random_state = 76     sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.921   RMSE = 2.870  Error_a1 = 0.045   Error_a2 = 0.318   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC
# model = rf          random_state = 89     sid = 22     feat_sel_thresh = 1.0    features = 6      R2 = 0.664   RMSE = 6.590  Error_a1 = 0.045   Error_a2 = 0.136   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = SCM
# model = rf          random_state = 89     sid = 120    feat_sel_thresh = 1.0    features = 6      R2 = 0.842   RMSE = 4.526  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 89     sid = 200    feat_sel_thresh = 1.0    features = 6      R2 = 0.628   RMSE = 6.939  Error_a1 = 0.000   Error_a2 = 0.136   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = SCM
# model = rf          random_state = 89     sid = 420    feat_sel_thresh = 1.0    features = 6      R2 = 0.851   RMSE = 4.398  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC_CaO
# model = rf          random_state = 89     sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.848   RMSE = 4.439  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC_CaO
# model = rf          random_state = 89     sid = 563    feat_sel_thresh = 1.0    features = 5      R2 = 0.659   RMSE = 6.642  Error_a1 = 0.045   Error_a2 = 0.182   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_CaO         Feat4 = SCM
# model = rf          random_state = 89     sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.847   RMSE = 4.453  Error_a1 = 0.136   Error_a2 = 0.318   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC_CaO
# model = rf          random_state = 89     sid = 739    feat_sel_thresh = 1.0    features = 6      R2 = 0.631   RMSE = 6.910  Error_a1 = 0.000   Error_a2 = 0.136   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 89     sid = 810    feat_sel_thresh = 1.0    features = 6      R2 = 0.862   RMSE = 4.231  Error_a1 = 0.045   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 89     sid = 914    feat_sel_thresh = 1.0    features = 6      R2 = 0.856   RMSE = 4.315  Error_a1 = 0.045   Error_a2 = 0.318   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_CaO         Feat4 = SCM
# model = rf          random_state = 140    sid = 22     feat_sel_thresh = 1.0    features = 7      R2 = 0.749   RMSE = 7.775  Error_a1 = 0.091   Error_a2 = 0.409   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC
# model = rf          random_state = 140    sid = 120    feat_sel_thresh = 1.0    features = 7      R2 = 0.776   RMSE = 7.335  Error_a1 = 0.091   Error_a2 = 0.545   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC             Feat4 = PC_CaO
# model = rf          random_state = 140    sid = 200    feat_sel_thresh = 1.0    features = 7      R2 = 0.762   RMSE = 7.561  Error_a1 = 0.091   Error_a2 = 0.455   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC
# model = rf          random_state = 140    sid = 420    feat_sel_thresh = 1.0    features = 7      R2 = 0.740   RMSE = 7.908  Error_a1 = 0.091   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = rf          random_state = 140    sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.615   RMSE = 9.627  Error_a1 = 0.182   Error_a2 = 0.455   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = SCM
# model = rf          random_state = 140    sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.787   RMSE = 7.159  Error_a1 = 0.136   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC_CaO
# model = rf          random_state = 140    sid = 680    feat_sel_thresh = 1.0    features = 6      R2 = 0.748   RMSE = 7.793  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC_CaO
# model = rf          random_state = 140    sid = 739    feat_sel_thresh = 1.0    features = 7      R2 = 0.750   RMSE = 7.753  Error_a1 = 0.091   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC
# model = rf          random_state = 140    sid = 810    feat_sel_thresh = 1.0    features = 7      R2 = 0.774   RMSE = 7.369  Error_a1 = 0.000   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = rf          random_state = 140    sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.773   RMSE = 7.384  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = SCM
# model = rf          random_state = 267    sid = 22     feat_sel_thresh = 1.0    features = 7      R2 = 0.343   RMSE = 7.612  Error_a1 = 0.091   Error_a2 = 0.364   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC_CaO
# model = rf          random_state = 267    sid = 120    feat_sel_thresh = 1.0    features = 7      R2 = 0.368   RMSE = 7.465  Error_a1 = 0.136   Error_a2 = 0.364   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC
# model = rf          random_state = 267    sid = 200    feat_sel_thresh = 1.0    features = 6      R2 = 0.315   RMSE = 7.771  Error_a1 = 0.091   Error_a2 = 0.409   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 267    sid = 420    feat_sel_thresh = 1.0    features = 7      R2 = 0.388   RMSE = 7.346  Error_a1 = 0.227   Error_a2 = 0.364   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_CaO         Feat4 = PC_K2O
# model = rf          random_state = 267    sid = 453    feat_sel_thresh = 1.0    features = 7      R2 = 0.390   RMSE = 7.338  Error_a1 = 0.136   Error_a2 = 0.364   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC_CaO
# model = rf          random_state = 267    sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.378   RMSE = 7.410  Error_a1 = 0.227   Error_a2 = 0.409   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 267    sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.326   RMSE = 7.713  Error_a1 = 0.182   Error_a2 = 0.364   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC_CaO
# model = rf          random_state = 267    sid = 739    feat_sel_thresh = 1.0    features = 7      R2 = 0.372   RMSE = 7.442  Error_a1 = 0.182   Error_a2 = 0.409   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC_CaO
# model = rf          random_state = 267    sid = 810    feat_sel_thresh = 1.0    features = 7      R2 = 0.398   RMSE = 7.287  Error_a1 = 0.182   Error_a2 = 0.227   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC_CaO
# model = rf          random_state = 267    sid = 914    feat_sel_thresh = 1.0    features = 6      R2 = 0.335   RMSE = 7.662  Error_a1 = 0.091   Error_a2 = 0.364   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_CaO         Feat4 = PC_K2O
# model = rf          random_state = 310    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.492   RMSE = 42.379  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_MgO       Feat2 = PC_CaO       Feat3 = PC_K2O         Feat4 = PC
# model = rf          random_state = 310    sid = 120    feat_sel_thresh = 1.0    features = 6      R2 = 0.485   RMSE = 42.672  Error_a1 = 0.045   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 310    sid = 200    feat_sel_thresh = 1.0    features = 7      R2 = 0.500   RMSE = 42.031  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_CaO         Feat4 = PC_C3A
# model = rf          random_state = 310    sid = 420    feat_sel_thresh = 1.0    features = 6      R2 = 0.457   RMSE = 43.817  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_CaO         Feat4 = PC_C3A
# model = rf          random_state = 310    sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.485   RMSE = 42.678  Error_a1 = 0.045   Error_a2 = 0.182   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_CaO         Feat4 = PC_C3A
# model = rf          random_state = 310    sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.514   RMSE = 41.437  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 310    sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.514   RMSE = 41.430  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = rf          random_state = 310    sid = 739    feat_sel_thresh = 1.0    features = 7      R2 = 0.562   RMSE = 39.365  Error_a1 = 0.091   Error_a2 = 0.364   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_CaO         Feat4 = SCM
# model = rf          random_state = 310    sid = 810    feat_sel_thresh = 1.0    features = 6      R2 = 0.473   RMSE = 43.160  Error_a1 = 0.045   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 310    sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.443   RMSE = 44.380  Error_a1 = 0.091   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_CaO         Feat4 = PC_C3A
# model = rf          random_state = 560    sid = 22     feat_sel_thresh = 1.0    features = 6      R2 = 0.688   RMSE = 6.492  Error_a1 = 0.045   Error_a2 = 0.182   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_CaO         Feat4 = PC
# model = rf          random_state = 560    sid = 120    feat_sel_thresh = 1.0    features = 6      R2 = 0.721   RMSE = 6.139  Error_a1 = 0.136   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 560    sid = 200    feat_sel_thresh = 1.0    features = 6      R2 = 0.709   RMSE = 6.271  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_CaO         Feat4 = PC
# model = rf          random_state = 560    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.741   RMSE = 5.925  Error_a1 = 0.182   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 560    sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.762   RMSE = 5.670  Error_a1 = 0.136   Error_a2 = 0.227   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_CaO         Feat4 = SCM
# model = rf          random_state = 560    sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.739   RMSE = 5.945  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 560    sid = 680    feat_sel_thresh = 1.0    features = 6      R2 = 0.692   RMSE = 6.451  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_CaO         Feat4 = SCM
# model = rf          random_state = 560    sid = 739    feat_sel_thresh = 1.0    features = 6      R2 = 0.692   RMSE = 6.453  Error_a1 = 0.227   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = rf          random_state = 560    sid = 810    feat_sel_thresh = 1.0    features = 6      R2 = 0.689   RMSE = 6.483  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 560    sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.757   RMSE = 5.730  Error_a1 = 0.136   Error_a2 = 0.227   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = C1_T
# model = rf          random_state = 771    sid = 22     feat_sel_thresh = 1.0    features = 7      R2 = 0.663   RMSE = 9.972  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_C3A       Feat2 = PC_MgO       Feat3 = PC_K2O         Feat4 = PC_CaO
# model = rf          random_state = 771    sid = 120    feat_sel_thresh = 1.0    features = 7      R2 = 0.785   RMSE = 7.974  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_C3A       Feat2 = PC_MgO       Feat3 = PC_K2O         Feat4 = SCM
# model = rf          random_state = 771    sid = 200    feat_sel_thresh = 1.0    features = 6      R2 = 0.456   RMSE = 12.679  Error_a1 = 0.091   Error_a2 = 0.182   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = SCM
# model = rf          random_state = 771    sid = 420    feat_sel_thresh = 1.0    features = 6      R2 = 0.857   RMSE = 6.490  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_C3A       Feat2 = PC_K2O       Feat3 = PC_MgO         Feat4 = PC_CaO
# model = rf          random_state = 771    sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.832   RMSE = 7.051  Error_a1 = 0.000   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 771    sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.854   RMSE = 6.570  Error_a1 = 0.000   Error_a2 = 0.273   Feat1 = PC_C3A       Feat2 = PC_MgO       Feat3 = PC_K2O         Feat4 = PC
# model = rf          random_state = 771    sid = 680    feat_sel_thresh = 1.0    features = 6      R2 = 0.828   RMSE = 7.122  Error_a1 = 0.045   Error_a2 = 0.364   Feat1 = PC_C3A       Feat2 = PC_MgO       Feat3 = PC_K2O         Feat4 = SCM
# model = rf          random_state = 771    sid = 739    feat_sel_thresh = 1.0    features = 7      R2 = 0.809   RMSE = 7.510  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = SCM
# model = rf          random_state = 771    sid = 810    feat_sel_thresh = 1.0    features = 7      R2 = 0.621   RMSE = 10.575  Error_a1 = 0.091   Error_a2 = 0.182   Feat1 = PC_C3A       Feat2 = PC_K2O       Feat3 = PC_MgO         Feat4 = PC
# model = rf          random_state = 771    sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.860   RMSE = 6.421  Error_a1 = 0.000   Error_a2 = 0.227   Feat1 = PC_C3A       Feat2 = PC_K2O       Feat3 = PC_MgO         Feat4 = SCM
# model = rf          random_state = 870    sid = 22     feat_sel_thresh = 1.0    features = 7      R2 = 0.835   RMSE = 12.086  Error_a1 = 0.045   Error_a2 = 0.318   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 870    sid = 120    feat_sel_thresh = 1.0    features = 7      R2 = 0.884   RMSE = 10.146  Error_a1 = 0.045   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC
# model = rf          random_state = 870    sid = 200    feat_sel_thresh = 1.0    features = 7      R2 = 0.867   RMSE = 10.851  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC_CaO
# model = rf          random_state = 870    sid = 420    feat_sel_thresh = 1.0    features = 7      R2 = 0.843   RMSE = 11.805  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 870    sid = 453    feat_sel_thresh = 1.0    features = 7      R2 = 0.883   RMSE = 10.180  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 870    sid = 563    feat_sel_thresh = 1.0    features = 6      R2 = 0.841   RMSE = 11.853  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC
# model = rf          random_state = 870    sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.886   RMSE = 10.041  Error_a1 = 0.000   Error_a2 = 0.409   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 870    sid = 739    feat_sel_thresh = 1.0    features = 6      R2 = 0.871   RMSE = 10.698  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 870    sid = 810    feat_sel_thresh = 1.0    features = 7      R2 = 0.898   RMSE = 9.521  Error_a1 = 0.136   Error_a2 = 0.409   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 870    sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.809   RMSE = 12.992  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 952    sid = 22     feat_sel_thresh = 1.0    features = 7      R2 = 0.730   RMSE = 6.528  Error_a1 = 0.000   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = SCM
# model = rf          random_state = 952    sid = 120    feat_sel_thresh = 1.0    features = 7      R2 = 0.701   RMSE = 6.872  Error_a1 = 0.000   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = C1_T
# model = rf          random_state = 952    sid = 200    feat_sel_thresh = 1.0    features = 6      R2 = 0.774   RMSE = 5.966  Error_a1 = 0.091   Error_a2 = 0.364   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = SCM
# model = rf          random_state = 952    sid = 420    feat_sel_thresh = 1.0    features = 6      R2 = 0.582   RMSE = 8.126  Error_a1 = 0.045   Error_a2 = 0.182   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = rf          random_state = 952    sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.672   RMSE = 7.199  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC_CaO
# model = rf          random_state = 952    sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.742   RMSE = 6.382  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_MgO       Feat2 = PC_K2O       Feat3 = PC_C3A         Feat4 = SCM
# model = rf          random_state = 952    sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.711   RMSE = 6.751  Error_a1 = 0.000   Error_a2 = 0.318   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = C1_T
# model = rf          random_state = 952    sid = 739    feat_sel_thresh = 1.0    features = 7      R2 = 0.683   RMSE = 7.075  Error_a1 = 0.045   Error_a2 = 0.273   Feat1 = PC_MgO       Feat2 = PC_C3A       Feat3 = PC_K2O         Feat4 = PC
# model = rf          random_state = 952    sid = 810    feat_sel_thresh = 1.0    features = 7      R2 = 0.718   RMSE = 6.669  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC
# model = rf          random_state = 952    sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.726   RMSE = 6.575  Error_a1 = 0.136   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC
# model = et          random_state = 20     sid = 22     feat_sel_thresh = 1.0    features = 6      R2 = 0.927   RMSE = 6.802  Error_a1 = 0.045   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = SCM            Feat4 = PC_MgO
# model = et          random_state = 20     sid = 120    feat_sel_thresh = 1.0    features = 6      R2 = 0.862   RMSE = 9.393  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = et          random_state = 20     sid = 200    feat_sel_thresh = 1.0    features = 6      R2 = 0.860   RMSE = 9.445  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 20     sid = 420    feat_sel_thresh = 1.0    features = 7      R2 = 0.940   RMSE = 6.204  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 20     sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.939   RMSE = 6.219  Error_a1 = 0.045   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 20     sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.940   RMSE = 6.209  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 20     sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.939   RMSE = 6.226  Error_a1 = 0.091   Error_a2 = 0.182   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 20     sid = 739    feat_sel_thresh = 1.0    features = 6      R2 = 0.915   RMSE = 7.347  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 20     sid = 810    feat_sel_thresh = 1.0    features = 6      R2 = 0.926   RMSE = 6.886  Error_a1 = 0.136   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 20     sid = 914    feat_sel_thresh = 1.0    features = 6      R2 = 0.862   RMSE = 9.374  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 76     sid = 22     feat_sel_thresh = 1.0    features = 7      R2 = 0.940   RMSE = 2.516  Error_a1 = 0.182   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = SCM            Feat4 = PC_C3A
# model = et          random_state = 76     sid = 120    feat_sel_thresh = 1.0    features = 6      R2 = 0.925   RMSE = 2.808  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC             Feat4 = PC_MgO
# model = et          random_state = 76     sid = 200    feat_sel_thresh = 1.0    features = 7      R2 = 0.934   RMSE = 2.635  Error_a1 = 0.091   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = SCM
# model = et          random_state = 76     sid = 420    feat_sel_thresh = 1.0    features = 6      R2 = 0.930   RMSE = 2.714  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC             Feat4 = PC_MgO
# model = et          random_state = 76     sid = 453    feat_sel_thresh = 1.0    features = 7      R2 = 0.933   RMSE = 2.644  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 76     sid = 563    feat_sel_thresh = 1.0    features = 6      R2 = 0.937   RMSE = 2.576  Error_a1 = 0.136   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = SCM
# model = et          random_state = 76     sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.937   RMSE = 2.570  Error_a1 = 0.136   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC             Feat4 = PC_C3A
# model = et          random_state = 76     sid = 739    feat_sel_thresh = 1.0    features = 6      R2 = 0.933   RMSE = 2.655  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = PC_MgO         Feat4 = PC_C3A
# model = et          random_state = 76     sid = 810    feat_sel_thresh = 1.0    features = 7      R2 = 0.932   RMSE = 2.665  Error_a1 = 0.091   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 76     sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.933   RMSE = 2.657  Error_a1 = 0.182   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = et          random_state = 89     sid = 22     feat_sel_thresh = 1.0    features = 6      R2 = 0.680   RMSE = 6.432  Error_a1 = 0.000   Error_a2 = 0.182   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = C1_T
# model = et          random_state = 89     sid = 120    feat_sel_thresh = 1.0    features = 6      R2 = 0.840   RMSE = 4.547  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 89     sid = 200    feat_sel_thresh = 1.0    features = 6      R2 = 0.663   RMSE = 6.605  Error_a1 = 0.000   Error_a2 = 0.182   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 89     sid = 420    feat_sel_thresh = 1.0    features = 6      R2 = 0.847   RMSE = 4.451  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = SCM
# model = et          random_state = 89     sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.842   RMSE = 4.523  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 89     sid = 563    feat_sel_thresh = 1.0    features = 5      R2 = 0.654   RMSE = 6.686  Error_a1 = 0.045   Error_a2 = 0.182   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 89     sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.849   RMSE = 4.421  Error_a1 = 0.136   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = et          random_state = 89     sid = 739    feat_sel_thresh = 1.0    features = 6      R2 = 0.660   RMSE = 6.628  Error_a1 = 0.000   Error_a2 = 0.136   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = SCM
# model = et          random_state = 89     sid = 810    feat_sel_thresh = 1.0    features = 6      R2 = 0.826   RMSE = 4.748  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = et          random_state = 89     sid = 914    feat_sel_thresh = 1.0    features = 6      R2 = 0.833   RMSE = 4.656  Error_a1 = 0.136   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 140    sid = 22     feat_sel_thresh = 1.0    features = 7      R2 = 0.735   RMSE = 7.980  Error_a1 = 0.045   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 140    sid = 120    feat_sel_thresh = 1.0    features = 7      R2 = 0.736   RMSE = 7.963  Error_a1 = 0.091   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 140    sid = 200    feat_sel_thresh = 1.0    features = 7      R2 = 0.751   RMSE = 7.736  Error_a1 = 0.136   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 140    sid = 420    feat_sel_thresh = 1.0    features = 7      R2 = 0.765   RMSE = 7.516  Error_a1 = 0.091   Error_a2 = 0.455   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = C1_T           Feat4 = PC_C3A
# model = et          random_state = 140    sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.607   RMSE = 9.726  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 140    sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.762   RMSE = 7.565  Error_a1 = 0.091   Error_a2 = 0.455   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 140    sid = 680    feat_sel_thresh = 1.0    features = 6      R2 = 0.759   RMSE = 7.608  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 140    sid = 739    feat_sel_thresh = 1.0    features = 7      R2 = 0.761   RMSE = 7.574  Error_a1 = 0.091   Error_a2 = 0.455   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = C1_T
# model = et          random_state = 140    sid = 810    feat_sel_thresh = 1.0    features = 7      R2 = 0.756   RMSE = 7.655  Error_a1 = 0.045   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 140    sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.758   RMSE = 7.629  Error_a1 = 0.091   Error_a2 = 0.455   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = C1_T           Feat4 = PC_C3A
# model = et          random_state = 267    sid = 22     feat_sel_thresh = 1.0    features = 7      R2 = 0.344   RMSE = 7.605  Error_a1 = 0.091   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = C1_T
# model = et          random_state = 267    sid = 120    feat_sel_thresh = 1.0    features = 7      R2 = 0.364   RMSE = 7.491  Error_a1 = 0.091   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = et          random_state = 267    sid = 200    feat_sel_thresh = 1.0    features = 6      R2 = 0.345   RMSE = 7.603  Error_a1 = 0.091   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 267    sid = 420    feat_sel_thresh = 1.0    features = 7      R2 = 0.341   RMSE = 7.623  Error_a1 = 0.136   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = et          random_state = 267    sid = 453    feat_sel_thresh = 1.0    features = 7      R2 = 0.360   RMSE = 7.511  Error_a1 = 0.136   Error_a2 = 0.455   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC_CaO
# model = et          random_state = 267    sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.387   RMSE = 7.354  Error_a1 = 0.136   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 267    sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.329   RMSE = 7.695  Error_a1 = 0.091   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 267    sid = 739    feat_sel_thresh = 1.0    features = 7      R2 = 0.359   RMSE = 7.522  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 267    sid = 810    feat_sel_thresh = 1.0    features = 7      R2 = 0.381   RMSE = 7.389  Error_a1 = 0.136   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 267    sid = 914    feat_sel_thresh = 1.0    features = 6      R2 = 0.295   RMSE = 7.887  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = et          random_state = 310    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.593   RMSE = 37.952  Error_a1 = 0.045   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = et          random_state = 310    sid = 120    feat_sel_thresh = 1.0    features = 6      R2 = 0.583   RMSE = 38.394  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC
# model = et          random_state = 310    sid = 200    feat_sel_thresh = 1.0    features = 7      R2 = 0.607   RMSE = 37.264  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 310    sid = 420    feat_sel_thresh = 1.0    features = 6      R2 = 0.556   RMSE = 39.631  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = et          random_state = 310    sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.585   RMSE = 38.303  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 310    sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.607   RMSE = 37.251  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = et          random_state = 310    sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.599   RMSE = 37.662  Error_a1 = 0.045   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC             Feat4 = PC_C3A
# model = et          random_state = 310    sid = 739    feat_sel_thresh = 1.0    features = 7      R2 = 0.603   RMSE = 37.469  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 310    sid = 810    feat_sel_thresh = 1.0    features = 6      R2 = 0.608   RMSE = 37.234  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC
# model = et          random_state = 310    sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.597   RMSE = 37.736  Error_a1 = 0.045   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = et          random_state = 560    sid = 22     feat_sel_thresh = 1.0    features = 6      R2 = 0.707   RMSE = 6.293  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = C1_T           Feat4 = PC_C3A
# model = et          random_state = 560    sid = 120    feat_sel_thresh = 1.0    features = 6      R2 = 0.696   RMSE = 6.416  Error_a1 = 0.136   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = C1_T           Feat4 = PC_C3A
# model = et          random_state = 560    sid = 200    feat_sel_thresh = 1.0    features = 6      R2 = 0.712   RMSE = 6.245  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = C1_T           Feat4 = PC
# model = et          random_state = 560    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.728   RMSE = 6.063  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_CaO         Feat4 = PC_C3A
# model = et          random_state = 560    sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.705   RMSE = 6.320  Error_a1 = 0.136   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = waterbinder
# model = et          random_state = 560    sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.694   RMSE = 6.434  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = C1_T           Feat4 = PC_C3A
# model = et          random_state = 560    sid = 680    feat_sel_thresh = 1.0    features = 6      R2 = 0.708   RMSE = 6.290  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 560    sid = 739    feat_sel_thresh = 1.0    features = 6      R2 = 0.753   RMSE = 5.776  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = C1_T           Feat4 = PC_C3A
# model = et          random_state = 560    sid = 810    feat_sel_thresh = 1.0    features = 6      R2 = 0.725   RMSE = 6.104  Error_a1 = 0.136   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 560    sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.676   RMSE = 6.617  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = C1_T           Feat4 = PC
# model = et          random_state = 771    sid = 22     feat_sel_thresh = 1.0    features = 7      R2 = 0.658   RMSE = 10.053  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC
# model = et          random_state = 771    sid = 120    feat_sel_thresh = 1.0    features = 7      R2 = 0.659   RMSE = 10.040  Error_a1 = 0.091   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 771    sid = 200    feat_sel_thresh = 1.0    features = 6      R2 = -0.066   RMSE = 17.745  Error_a1 = 0.045   Error_a2 = 0.136   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = SCM
# model = et          random_state = 771    sid = 420    feat_sel_thresh = 1.0    features = 6      R2 = 0.673   RMSE = 9.822  Error_a1 = 0.000   Error_a2 = 0.182   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC
# model = et          random_state = 771    sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.660   RMSE = 10.022  Error_a1 = 0.000   Error_a2 = 0.136   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = waterbinder
# model = et          random_state = 771    sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.658   RMSE = 10.051  Error_a1 = 0.091   Error_a2 = 0.182   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC
# model = et          random_state = 771    sid = 680    feat_sel_thresh = 1.0    features = 6      R2 = 0.659   RMSE = 10.040  Error_a1 = 0.045   Error_a2 = 0.182   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = SCM
# model = et          random_state = 771    sid = 739    feat_sel_thresh = 1.0    features = 7      R2 = 0.658   RMSE = 10.053  Error_a1 = 0.045   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = SCM
# model = et          random_state = 771    sid = 810    feat_sel_thresh = 1.0    features = 7      R2 = 0.653   RMSE = 10.128  Error_a1 = 0.091   Error_a2 = 0.182   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC
# model = et          random_state = 771    sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.648   RMSE = 10.194  Error_a1 = 0.000   Error_a2 = 0.227   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 870    sid = 22     feat_sel_thresh = 1.0    features = 7      R2 = 0.899   RMSE = 9.464  Error_a1 = 0.091   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 870    sid = 120    feat_sel_thresh = 1.0    features = 7      R2 = 0.902   RMSE = 9.323  Error_a1 = 0.136   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 870    sid = 200    feat_sel_thresh = 1.0    features = 7      R2 = 0.901   RMSE = 9.365  Error_a1 = 0.045   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC_CaO
# model = et          random_state = 870    sid = 420    feat_sel_thresh = 1.0    features = 7      R2 = 0.899   RMSE = 9.450  Error_a1 = 0.136   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 870    sid = 453    feat_sel_thresh = 1.0    features = 7      R2 = 0.904   RMSE = 9.218  Error_a1 = 0.091   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = PC_CaO
# model = et          random_state = 870    sid = 563    feat_sel_thresh = 1.0    features = 6      R2 = 0.901   RMSE = 9.349  Error_a1 = 0.091   Error_a2 = 0.273   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = et          random_state = 870    sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.902   RMSE = 9.340  Error_a1 = 0.091   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 870    sid = 739    feat_sel_thresh = 1.0    features = 6      R2 = 0.909   RMSE = 8.977  Error_a1 = 0.136   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = et          random_state = 870    sid = 810    feat_sel_thresh = 1.0    features = 7      R2 = 0.898   RMSE = 9.506  Error_a1 = 0.045   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 870    sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.898   RMSE = 9.509  Error_a1 = 0.136   Error_a2 = 0.409   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 952    sid = 22     feat_sel_thresh = 1.0    features = 7      R2 = 0.783   RMSE = 5.855  Error_a1 = 0.136   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 952    sid = 120    feat_sel_thresh = 1.0    features = 7      R2 = 0.786   RMSE = 5.819  Error_a1 = 0.136   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 952    sid = 200    feat_sel_thresh = 1.0    features = 6      R2 = 0.824   RMSE = 5.266  Error_a1 = 0.045   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 952    sid = 420    feat_sel_thresh = 1.0    features = 6      R2 = 0.589   RMSE = 8.055  Error_a1 = 0.045   Error_a2 = 0.182   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 952    sid = 453    feat_sel_thresh = 1.0    features = 6      R2 = 0.792   RMSE = 5.723  Error_a1 = 0.045   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = PC_CaO
# model = et          random_state = 952    sid = 563    feat_sel_thresh = 1.0    features = 7      R2 = 0.783   RMSE = 5.854  Error_a1 = 0.136   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 952    sid = 680    feat_sel_thresh = 1.0    features = 7      R2 = 0.783   RMSE = 5.848  Error_a1 = 0.045   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = C1_T           Feat4 = PC_C3A
# model = et          random_state = 952    sid = 739    feat_sel_thresh = 1.0    features = 7      R2 = 0.773   RMSE = 5.992  Error_a1 = 0.045   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
# model = et          random_state = 952    sid = 810    feat_sel_thresh = 1.0    features = 7      R2 = 0.774   RMSE = 5.971  Error_a1 = 0.091   Error_a2 = 0.318   Feat1 = PC_K2O       Feat2 = PC_C3A       Feat3 = PC_MgO         Feat4 = C1_T
# model = et          random_state = 952    sid = 914    feat_sel_thresh = 1.0    features = 7      R2 = 0.779   RMSE = 5.903  Error_a1 = 0.136   Error_a2 = 0.364   Feat1 = PC_K2O       Feat2 = PC_MgO       Feat3 = PC_C3A         Feat4 = C1_T
#     model random_state  sid kfold  ...      3N        3V      4N        4V
# 0      rf           20   22     5  ...  PC_C3A  0.295165     SCM   0.29436
# 1      rf           20  120     5  ...  PC_CaO  0.379528      PC  0.379522
# 2      rf           20  200     5  ...  PC_CaO  0.383167     SCM  0.382937
# 3      rf           20  420     5  ...  PC_C3A  0.431281     SCM  0.356507
# 4      rf           20  453     5  ...  PC_CaO  0.379757     SCM  0.377537
# ..    ...          ...  ...   ...  ...     ...       ...     ...       ...
# 195    et          952  563     5  ...  PC_C3A  0.427733    C1_T  0.322886
# 196    et          952  680     5  ...    C1_T  0.316787  PC_C3A  0.311761
# 197    et          952  739     5  ...  PC_C3A  0.343924    C1_T   0.29343
# 198    et          952  810     5  ...  PC_MgO  0.366573    C1_T  0.315836
# 199    et          952  914     5  ...  PC_C3A  0.326385    C1_T  0.297848
#
# [200 rows x 18 columns]
