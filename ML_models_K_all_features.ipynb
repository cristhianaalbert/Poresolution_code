# %% [markdown]
# <a href="https://colab.research.google.com/github/cristhianaalbert/Poresolution_code/blob/Machine-learning-models/ML_models_K_all_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Initial setup

# %%
# !pip install requests==2.23.0 folium==0.2.1 imgaug==0.2.6 pycaret pandas shap 
from pycaret.utils import enable_colab
enable_colab()

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pycaret.utils import check_metric
from pycaret.regression import *

# %%
def count_alpha_error (a, alpha=0.1):

    '''Calculates the percentage of elements inside a +- alpha range around the true measured value of the ion;
     a = array with final predictions on unseen data;
     alpha = range of error
    '''
    error = a.Kpredicted / a.K                           #when we are dealing with log scale of ion, the analysis is still in absolute terms;
    count = error[((1-alpha) < error) & (error <(1+alpha))].size
    total = len(error)
    return count/total
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %% [markdown]
# Load dataset

# %%
from google.colab import files
uploaded = files.upload()
import io
#dataset = pd.read_csv(io.StringIO(uploaded['datasetMPKlogK.csv'].decode('utf-8')))
dataset = pd.read_csv(io.StringIO(uploaded['database_K_sel_1.csv'].decode('utf-8')),sep=',')

dataset.head()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#      <input type="file" id="files-63002d27-27dd-434a-aca1-b7fe06f9756f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63002d27-27dd-434a-aca1-b7fe06f9756f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving database_K_sel_1.csv to database_K_sel_1.csv
#    Index    PC  SCM1  SCM1_type  SCM2  SCM2_type  PC_Na2O  PC_K2O  SCM1_SiO2  \
# 0      9  0.53  0.47          3  0.00          0     0.07    0.65      34.87
# 1     10  0.53  0.47          3  0.00          0     0.07    0.65      34.87
# 2     19  0.53  0.38          3  0.09          5     0.07    0.65      34.87
# 3     20  0.53  0.38          3  0.09          5     0.07    0.65      34.87
# 4     29  0.53  0.38          3  0.09          7     0.07    0.65      34.87
#
#    SCM1_Al2O3  SCM2_SiO2  SCM2_Al2O3     logK      K
# 0       11.62        0.0         0.0  2.15534  143.0
# 1       11.62        0.0         0.0  2.16732  147.0
# 2       11.62        2.0         0.8  2.14613  140.0
# 3       11.62        2.0         0.8  2.15534  143.0
# 4       11.62      100.0         0.0  2.19312  156.0

# %% [markdown]
# Visualize data

# %%
## combine these different collections into a list
mixproportion = [dataset.PC, dataset.SCM1, dataset.SCM2]
#mixproportion = [dataset.waterbinder]
sns.set_theme(style="white")

# Create a figure instance
fig = plt.figure()
# Create an axes instance
ax = fig.add_axes([0,0,1,1])
ax.set_ylabel('Mix proportion')
#ax.set_xlabel('Sample name') ['PC', 'SCM1', 'SCM2', 'w/b'] LEARN HOW TO SET THESE AXIS
# Create the boxplot
bp = ax.violinplot(mixproportion)
plt.show()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
## combine these different collections into a list
mixproportion = [10**dataset.logK]
#mixproportion = [dataset.waterbinder]
sns.set_theme(style="white")

# Create a figure instance
fig = plt.figure()
# Create an axes instance
ax = fig.add_axes([0,0,1,1])
ax.set_ylabel('Mix proportion')
#ax.set_xlabel('Sample name') ['PC', 'SCM1', 'SCM2', 'w/b'] LEARN HOW TO SET THESE AXIS
# Create the boxplot
bp = ax.violinplot(mixproportion)
plt.show()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
fig, ax = plt.subplots()
sns.set_theme(style="white")
#sns.set_palette(sns.color_palette('Paired'))
mixproportion = [10**dataset.logK]
sns.histplot(data=mixproportion, binwidth=0.01, log_scale=True,color='r', legend='K')
#ax1.set_ylim(0, 30)
#plt.setp(ax, xticks=[10,100,1000])
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
display(dataset.shape)
dataset.describe()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# (214, 14)
#             Index          PC        SCM1   SCM1_type        SCM2   SCM2_type  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean   413.247664    0.824860    0.154252    1.224299    0.021168    0.359813
# std    264.941520    0.224463    0.190128    1.351809    0.079535    1.157329
# min      9.000000    0.200000    0.000000    0.000000    0.000000    0.000000
# 25%    178.250000    0.700000    0.000000    0.000000    0.000000    0.000000
# 50%    368.500000    0.940000    0.060000    1.000000    0.000000    0.000000
# 75%    602.750000    1.000000    0.300000    2.000000    0.000000    0.000000
# max    999.000000    1.000000    0.750000    5.000000    0.480000    7.000000
#
#           PC_Na2O      PC_K2O   SCM1_SiO2  SCM1_Al2O3   SCM2_SiO2  SCM2_Al2O3  \
# count  191.000000  187.000000  191.000000  196.000000  214.000000  214.000000
# mean     0.239319    0.618930   32.419686    6.267694    3.938785    1.083645
# std      0.180843    0.347283   38.435623   15.082531   15.427429    4.763256
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.130000    0.290000    0.000000    0.000000    0.000000    0.000000
# 50%      0.180000    0.540000    0.800000    0.000000    0.000000    0.000000
# 75%      0.410000    0.890000   49.780000    8.900000    0.000000    0.000000
# max      0.900000    1.230000   98.700000   85.530000  100.000000   26.900000
#
#              logK           K
# count  214.000000  214.000000
# mean     2.022195  216.889720
# std      0.674229  210.494511
# min     -0.117940    0.800000
# 25%      1.730827   53.825000
# 50%      2.156850  143.500000
# 75%      2.480010  302.000000
# max      2.932980  857.000000

# %%
SCM = dataset.SCM1 + dataset.SCM2
SCM_SiO2 = ( dataset.SCM1*dataset.SCM1_SiO2 + dataset.SCM2*dataset.SCM2_SiO2 ) / SCM
SCM_Al2O3 =( dataset.SCM1*dataset.SCM1_Al2O3 + dataset.SCM2*dataset.SCM2_Al2O3 ) / SCM
dataset.insert(dataset.shape[1],'SCM', SCM)
dataset.insert(dataset.shape[1],'SCM_SiO2', SCM_SiO2)
dataset.insert(dataset.shape[1],'SCM_Al2O3', SCM_Al2O3)
dataset.drop(['SCM1','SCM2','SCM1_type','SCM2_type','SCM1_SiO2','SCM1_Al2O3','SCM2_SiO2','SCM2_Al2O3'],axis=1,inplace=True)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %% [markdown]
# # Modeling

# %%
#defining initial parameters

model_list = ['rf','et']                        #models to be tested;
seed_list = [76,89,140,267,870]                       #seeds for separating data to train/test model and for final predictions; 
sid_list = [22,453,563,914]                         #seeds for session id on setup - I believe it defines how cross-validation groups are defined;
featsel_list = [1.0, 0.4, 0.3,0.2,0.15]         #feature_selection_threshold for setup - defines how many features will be considered in the model (train/test/prediction);
featsel_list = [1.0]         #feature_selection_threshold for setup - defines how many features will be considered in the model (train/test/prediction);
seed_list = [20, 76,89,140,267,310, 560, 771, 870, 952]                       #seeds for separating data to train/test model and for final predictions; 
sid_list = [22,120, 200, 420, 453, 563, 680, 739, 810, 914]                         #seeds for session id on setup - I believe it defines how cross-validation groups are defined;
kfold_list = [5]                            #numbers of folds for cross-validation - I didn't notice differences on the final results;


alpha1=0.1                                   #error range - used to evaluate +-10% error of prediction around the measured value;
alpha2=0.25                                  #error range - used to evaluate +-25% error of prediction around the measured value;
i=0                                          #initial index;

#tunemodel
tune_on = 1   # 1 to avoid tuning of hyperparameteres; 2 to allow tuning of hyperparameteres;
#These parameters are focused on decision tree methods;
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 20, stop = 100, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 10, num = 5)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
tune_params = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
                        

totalsystems = len(model_list)*len(seed_list)*len(sid_list)*len(featsel_list)*len(kfold_list)*tune_on   #total number of systems considering all variables; times 2 because we have tuned models
totalcolumns = 10                                                                                 #depends on the statistic variables stored on the array "summary" (modelname, ..., R2, RMSE, alpha, etc)
summary = np.zeros((totalsystems, totalcolumns),dtype=object)                                     #array summary mentioned above;

#REMEMBER TO ALTER DEPENDING ON THE SIZE OF DATASET (HOW MANY VARIABLES IT HAS)
estimativefeat = round(int(2*dataset.shape[1]))                        #depends on the number of features in dataset - needs to be a little bit bigger to account for categorical features that are transformed (one hot encoding method)
mostimpfeat = 4                          #number of most important features to be analysed; 15 or 10 seems a reasonable number;


mostimpfeat_value = np.ndarray(shape=(totalsystems, mostimpfeat+1),dtype=object)                      #arrays to store most important features properties; plus 1 is for indexing modelname
mostimpfeat_name = np.zeros(shape=(totalsystems, mostimpfeat+1),dtype=object)
mostimpfeat_test = np.zeros(shape=(totalsystems, 2*mostimpfeat+1),dtype=object)

feat_summary=[]

mostimpfeat_value_full = np.zeros(shape=(totalsystems, estimativefeat),dtype=float)               #arrays to store all features properties
mostimpfeat_name_full = np.zeros(shape=(totalsystems, estimativefeat),dtype=object)
mostimpfeat_full_summary = []


#numfeat = ['SCM2_Amorphous','C1_T','C2_Age_days','C2_T','Pressure_MPa']
ignfeat = ['Index',"K"]
numfeat = ['waterbinder','aggregatesbinder',
           'PC','SCM1','SCM2','PC_CaO','PC_SiO2','PC_Al2O3', 'PC_Fe2O3', 'PC_SO3', 'PC_MgO', 'PC_Na2O', 'PC_K2O', 
           'PC_TiO2', 'PC_P2O5', 'PC_MnO', 'PC_CO2','PC_LOI', 'PC_Amorphous', 'PC_C3S', 'PC_C2S', 'PC_C3A', 'PC_C4AF','PC_Blaine','PC_BET',
           'SCM1_CaO',	'SCM1_SiO2',	'SCM1_Al2O3',	'SCM1_Fe2O3',	'SCM1_SO3',	'SCM1_MgO',	'SCM1_Na2O',	'SCM1_K2O',	
           'SCM1_TiO2',	'SCM1_P2O5',	'SCM1_MnO',	'SCM1_CO2',	'SCM1_LOI','SCM1_Amorphous','SCM1_Blaine','SCM1_BET',
           'SCM2_CaO',	'SCM2_SiO2',	'SCM2_Al2O3',	'SCM2_Fe2O3',	'SCM2_SO3',	'SCM2_MgO',	'SCM2_Na2O',	'SCM2_K2O',	
           'SCM2_TiO2',	'SCM2_P2O5',	'SCM2_MnO',	'SCM2_CO2',	'SCM2_LOI','SCM2_Amorphous','SCM2_Blaine','SCM2_BET',
           'C1_Age_days','C1_RH','C1_T','C2_Age_days','C2_RH','C2_T','Final_age_days','Pressure_MPa']

numfeat = ['PC','SCM','PC_Na2O','PC_K2O','SCM_SiO2','SCM_Al2O3']



for modelname in model_list:                                #running for different models at same loop;
  for p in range(tune_on):                                                                                          #creating a normal and tuned version of the model  %TO AVOID HAVING TUNED MODELS, JUST PUT THE RANGE TO 1 INSTEAD OF 2

    for seed in seed_list:                                                                                      #running for different initial seeds for ramdom state - separation of data to train/test model and for final predictions;
      data = dataset.sample(frac=0.85, random_state=seed)
      data_unseen = dataset.drop(data.index)
      data.reset_index(drop=True, inplace=True)
      data_unseen.reset_index(drop=True, inplace=True)

      for sid in sid_list:                                                                                      #running for different seeds for session id on setup - I believe it defines how cross-validation groups are defined;
        for featsel in featsel_list:                                                                            #running different feature_selection_threshold for setup - defines how many features will be considered in the model (train/test/prediction)

          exp_ps = setup(data = data, target = 'logK', session_id=sid, normalize = True, 
                        combine_rare_levels = True, rare_level_threshold = 0.05,
                        remove_outliers = True, log_experiment = True, experiment_name = 'poresolution',
                        numeric_features = numfeat, fold=5, ignore_features = ignfeat,
                        feature_selection = True, silent=True, verbose=False)

          for kfold in kfold_list:                          #running for different numbers of folds for cross-validation - I didn't notice differences on the final results;
            #model = create_model(modelname,fold=kfold, n_estimators=80,max_depth=10, verbose=False)
            model = create_model(modelname,n_estimators=80,max_depth=8,fold=kfold,verbose=False)


            if p == 0:                                      #normal model
              model = model           
              modelnameb = modelname

            if p == 1:                                      #tuned model
              model = tune_model(model,fold=kfold, optimize="RMSE", verbose=False)
              modelnameb = 'tuned_'+str(modelname)
            
            aaa=get_logs()

            final_model = finalize_model(model)
            unseen_predictions = predict_model(final_model, data=data_unseen, round=None)
            #test_predictions = predict_model(final_model, data=data_testprediction, round=None)

            #checking accuracy of predictions on unseen data - R2, RMSE, fraction of predictions within alpha error range;
            a = unseen_predictions
            alinear = pd.DataFrame([np.array(10**a.logK), np.array(10**a.Label)]).T
            alinear.columns=["K","Kpredicted"]            
            R2 = check_metric(alinear.K, alinear.Kpredicted, 'R2' )     
            RMSE = check_metric(alinear.K, alinear.Kpredicted, 'RMSE' )
            erroralpha1 = count_alpha_error(alinear, alpha1)
            erroralpha2 = count_alpha_error(alinear, alpha2)

            nfeat = get_config('X_train').shape[1]           #number of features considered by model - depends on feature_selection_threshold;               

            summary[i,:] = ([modelnameb, seed, sid, kfold, featsel,nfeat, R2, RMSE, erroralpha1, erroralpha2])     #storing all these metrics for each system;


            featimp = pd.DataFrame({'Feature': get_config('X_train').columns, 'Value' : abs(final_model.feature_importances_)})    #getting the feature importance scores for all systems;
            featimpsort = featimp.sort_values(by='Value', ascending=False)[:mostimpfeat]                                           #organizing feature importance scores in descending order of importance;
            
            feat1 = np.array(featimpsort)[0,0]            #1st to 5th most important feature -> to be displayed during evaluations -> important to checks during runs;
            feat2 = np.array(featimpsort)[1,0]
            feat3 = np.array(featimpsort)[2,0]
            feat4 = np.array(featimpsort)[3,0]
            #feat5 = np.array(featimpsort)[4,0]

            mostimpfeat_name[i][0] = modelnameb                                                      #indexing the modelnameb to later identify where did the features get the most contribution
            mostimpfeat_value[i][0] = modelnameb                                                     #indexing the modelnameb to later identify where did the features get the most contribution
            for j in range(mostimpfeat):                                                             #arranging names and values of most important features in two arrays; 
              mostimpfeat_name[i][j+1] = np.array(featimpsort)[j,0]                                  #feature name
              mostimpfeat_value[i][j+1] = np.array(featimpsort)[j,1]/np.array(featimpsort)[0,1]      #feature importance value normalized in relation to most important feature;

            mostimpfeat_test[i][0] = modelnameb                                                      #indexing the modelnameb to later identify where did the features get the most contribution
            for j in range(mostimpfeat):                                                             #arranging names and values of most important features in one array; -> best method;
              mostimpfeat_test[i][2*j+1] = np.array(featimpsort)[j,0]                                #feature name
              mostimpfeat_test[i][2*j+2] = np.array(featimpsort)[j,1]/np.array(featimpsort)[0,1]     #feature importance value normalized in relation to most important feature;


            for k in range(nfeat):                                                                   #arranging names and values of all features in two arrays; 
              mostimpfeat_name_full[i][k] = np.array(featimp)[k,0]                                   #feature name
              mostimpfeat_value_full[i][k] = np.array(featimp)[k,1]/np.array(featimpsort)[0,1]       #feature importance value normalized in relation to most important feature;

            
            for ida, system in enumerate(mostimpfeat_name_full):          #arranging names and values of most important features in one array; -> best method;
              for idb, name in enumerate(system):
                value = mostimpfeat_value_full[ida][idb]
                mostimpfeat_full_summary.append([ida,idb,name,value])      

            i=i+1                                                         #finishing round and going to next one; increasing index number accordingly;

        #print('random_state=',seed,'  session_id=',sid,'  kfold=',kfold,'  R2=', R2, '  RMSE=', RMSE)
            print('''model = {: <10}  random_state = {: <5}  sid = {: <5}  feat_sel_thresh = {: <5}  features = {:<5}  R2 = {:.3f}   RMSE = {:.3f}  Error_a1 = {:.3f}   Error_a2 = {:.3f}   Feat1 = {: <10}   Feat2 = {: <10}   Feat3 = {: <10}     Feat4 = {: <10}   '''
                    .format(modelnameb,seed,sid,featsel, nfeat, R2, RMSE,erroralpha1, erroralpha2, feat1, feat2, feat3, feat4))


pd.DataFrame(mostimpfeat_test).to_csv('mostimpfeat_test.csv',index=False)

table_summary = pd.DataFrame(summary)                 #creating table of statistics for all systems;
table_summary.columns = ['model','random_state','sid','kfold','feat_sel_thresh','features','R2','RMSE','Error_alpha_0.1','Error_alpha_0.25']


columnname = []                                       #creating column names for most important features - we might change the number of selected features 
for i in range(mostimpfeat):
  columnname.append(str(i+1)+'N')
  columnname.append(str(i+1)+'V')

table_mostimpfeat = pd.DataFrame(mostimpfeat_test[:,1:])    #creating table of most important features with their name and value/score;
table_mostimpfeat.columns = columnname

finaltable = pd.concat([table_summary, table_mostimpfeat], axis=1, join='inner')   #combining statistics and most imp features in only one table; it helps on converting it to only one csv file later.
finaltable.to_csv('finaltable.csv')
display(finaltable)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# model = rf          random_state = 20     sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.947   RMSE = 57.353  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.943   RMSE = 59.331  Error_a1 = 0.219   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.942   RMSE = 59.690  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.935   RMSE = 63.003  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.941   RMSE = 60.345  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 563    feat_sel_thresh = 1.0    features = 5      R2 = 0.922   RMSE = 69.175  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 680    feat_sel_thresh = 1.0    features = 5      R2 = 0.945   RMSE = 58.366  Error_a1 = 0.312   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.941   RMSE = 60.286  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.946   RMSE = 57.751  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.950   RMSE = 55.277  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = rf          random_state = 76     sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.750   RMSE = 104.426  Error_a1 = 0.281   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 76     sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.749   RMSE = 104.805  Error_a1 = 0.250   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 76     sid = 200    feat_sel_thresh = 1.0    features = 4      R2 = 0.746   RMSE = 105.336  Error_a1 = 0.188   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = rf          random_state = 76     sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.740   RMSE = 106.654  Error_a1 = 0.219   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 76     sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.754   RMSE = 103.618  Error_a1 = 0.250   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 76     sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.758   RMSE = 102.758  Error_a1 = 0.281   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 76     sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.736   RMSE = 107.410  Error_a1 = 0.250   Error_a2 = 0.438   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 76     sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.756   RMSE = 103.315  Error_a1 = 0.312   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 76     sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.746   RMSE = 105.299  Error_a1 = 0.281   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 76     sid = 914    feat_sel_thresh = 1.0    features = 5      R2 = 0.758   RMSE = 102.833  Error_a1 = 0.250   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.899   RMSE = 70.034  Error_a1 = 0.219   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.892   RMSE = 72.425  Error_a1 = 0.188   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.899   RMSE = 69.949  Error_a1 = 0.219   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.888   RMSE = 73.507  Error_a1 = 0.219   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.901   RMSE = 69.351  Error_a1 = 0.250   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 563    feat_sel_thresh = 1.0    features = 5      R2 = 0.885   RMSE = 74.663  Error_a1 = 0.188   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.892   RMSE = 72.165  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.918   RMSE = 62.794  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.899   RMSE = 69.797  Error_a1 = 0.188   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.896   RMSE = 70.956  Error_a1 = 0.219   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 140    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.878   RMSE = 65.936  Error_a1 = 0.281   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 140    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.832   RMSE = 77.265  Error_a1 = 0.219   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 140    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.892   RMSE = 61.924  Error_a1 = 0.219   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 140    sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.871   RMSE = 67.606  Error_a1 = 0.250   Error_a2 = 0.688   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 140    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.873   RMSE = 67.135  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = PC           Feat3 = PC_Na2O        Feat4 = SCM_SiO2
# model = rf          random_state = 140    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.863   RMSE = 69.733  Error_a1 = 0.125   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = PC_Na2O        Feat4 = SCM_SiO2
# model = rf          random_state = 140    sid = 680    feat_sel_thresh = 1.0    features = 5      R2 = 0.850   RMSE = 72.915  Error_a1 = 0.219   Error_a2 = 0.688   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 140    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.850   RMSE = 73.025  Error_a1 = 0.250   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 140    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.874   RMSE = 67.011  Error_a1 = 0.156   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = rf          random_state = 140    sid = 914    feat_sel_thresh = 1.0    features = 5      R2 = 0.845   RMSE = 74.292  Error_a1 = 0.188   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.625   RMSE = 129.522  Error_a1 = 0.125   Error_a2 = 0.375   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.625   RMSE = 129.458  Error_a1 = 0.125   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.617   RMSE = 130.903  Error_a1 = 0.094   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.613   RMSE = 131.611  Error_a1 = 0.156   Error_a2 = 0.531   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.617   RMSE = 130.969  Error_a1 = 0.125   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.607   RMSE = 132.678  Error_a1 = 0.156   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.616   RMSE = 131.062  Error_a1 = 0.156   Error_a2 = 0.531   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.601   RMSE = 133.620  Error_a1 = 0.156   Error_a2 = 0.531   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.622   RMSE = 130.113  Error_a1 = 0.125   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 914    feat_sel_thresh = 1.0    features = 5      R2 = 0.608   RMSE = 132.466  Error_a1 = 0.094   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.643   RMSE = 118.473  Error_a1 = 0.344   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.672   RMSE = 113.615  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.662   RMSE = 115.430  Error_a1 = 0.281   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.630   RMSE = 120.622  Error_a1 = 0.344   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 453    feat_sel_thresh = 1.0    features = 5      R2 = 0.633   RMSE = 120.130  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.643   RMSE = 118.567  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.674   RMSE = 113.307  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.660   RMSE = 115.772  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.650   RMSE = 117.452  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 914    feat_sel_thresh = 1.0    features = 5      R2 = 0.663   RMSE = 115.153  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 560    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.903   RMSE = 68.598  Error_a1 = 0.406   Error_a2 = 0.719   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 560    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.897   RMSE = 70.579  Error_a1 = 0.281   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = PC_Na2O        Feat4 = SCM_SiO2
# model = rf          random_state = 560    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.901   RMSE = 69.266  Error_a1 = 0.344   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 560    sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.913   RMSE = 65.084  Error_a1 = 0.375   Error_a2 = 0.719   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 560    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.905   RMSE = 67.814  Error_a1 = 0.375   Error_a2 = 0.719   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 560    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.901   RMSE = 69.370  Error_a1 = 0.344   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 560    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.907   RMSE = 67.132  Error_a1 = 0.375   Error_a2 = 0.719   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 560    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.888   RMSE = 73.783  Error_a1 = 0.375   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 560    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.899   RMSE = 70.008  Error_a1 = 0.375   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 560    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.896   RMSE = 71.018  Error_a1 = 0.406   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.933   RMSE = 50.084  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.933   RMSE = 49.896  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 200    feat_sel_thresh = 1.0    features = 4      R2 = 0.938   RMSE = 48.239  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.934   RMSE = 49.645  Error_a1 = 0.281   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 453    feat_sel_thresh = 1.0    features = 5      R2 = 0.931   RMSE = 50.701  Error_a1 = 0.188   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.941   RMSE = 46.974  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.934   RMSE = 49.568  Error_a1 = 0.250   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.931   RMSE = 50.624  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.933   RMSE = 49.988  Error_a1 = 0.250   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.933   RMSE = 49.995  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 870    sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.843   RMSE = 68.156  Error_a1 = 0.281   Error_a2 = 0.531   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 870    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.861   RMSE = 64.253  Error_a1 = 0.250   Error_a2 = 0.531   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 870    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.851   RMSE = 66.552  Error_a1 = 0.375   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 870    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.868   RMSE = 62.565  Error_a1 = 0.281   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 870    sid = 453    feat_sel_thresh = 1.0    features = 5      R2 = 0.859   RMSE = 64.692  Error_a1 = 0.281   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 870    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.839   RMSE = 69.007  Error_a1 = 0.281   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 870    sid = 680    feat_sel_thresh = 1.0    features = 5      R2 = 0.835   RMSE = 69.835  Error_a1 = 0.312   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 870    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.880   RMSE = 59.498  Error_a1 = 0.281   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 870    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.851   RMSE = 66.545  Error_a1 = 0.312   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 870    sid = 914    feat_sel_thresh = 1.0    features = 5      R2 = 0.851   RMSE = 66.360  Error_a1 = 0.219   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 952    sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.640   RMSE = 137.820  Error_a1 = 0.219   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 952    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.656   RMSE = 134.753  Error_a1 = 0.375   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 952    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.617   RMSE = 142.174  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 952    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.630   RMSE = 139.739  Error_a1 = 0.344   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 952    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.655   RMSE = 134.995  Error_a1 = 0.344   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 952    sid = 563    feat_sel_thresh = 1.0    features = 5      R2 = 0.633   RMSE = 139.128  Error_a1 = 0.344   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 952    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.607   RMSE = 144.127  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 952    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.630   RMSE = 139.781  Error_a1 = 0.344   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 952    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.620   RMSE = 141.598  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 952    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.633   RMSE = 139.123  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.920   RMSE = 69.943  Error_a1 = 0.344   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.919   RMSE = 70.552  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.910   RMSE = 74.317  Error_a1 = 0.250   Error_a2 = 0.531   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.915   RMSE = 72.382  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.916   RMSE = 71.638  Error_a1 = 0.406   Error_a2 = 0.562   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 563    feat_sel_thresh = 1.0    features = 5      R2 = 0.918   RMSE = 71.027  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 680    feat_sel_thresh = 1.0    features = 5      R2 = 0.913   RMSE = 73.249  Error_a1 = 0.219   Error_a2 = 0.562   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.920   RMSE = 70.002  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.916   RMSE = 71.874  Error_a1 = 0.281   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.912   RMSE = 73.529  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.723   RMSE = 110.027  Error_a1 = 0.406   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.723   RMSE = 109.981  Error_a1 = 0.344   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 200    feat_sel_thresh = 1.0    features = 4      R2 = 0.733   RMSE = 108.013  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.716   RMSE = 111.446  Error_a1 = 0.406   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.738   RMSE = 107.052  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.713   RMSE = 111.992  Error_a1 = 0.406   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.706   RMSE = 113.412  Error_a1 = 0.312   Error_a2 = 0.531   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.730   RMSE = 108.630  Error_a1 = 0.406   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.729   RMSE = 108.793  Error_a1 = 0.344   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 914    feat_sel_thresh = 1.0    features = 5      R2 = 0.731   RMSE = 108.442  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.907   RMSE = 66.986  Error_a1 = 0.344   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.932   RMSE = 57.341  Error_a1 = 0.250   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.915   RMSE = 64.245  Error_a1 = 0.312   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.924   RMSE = 60.762  Error_a1 = 0.281   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.922   RMSE = 61.519  Error_a1 = 0.281   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 563    feat_sel_thresh = 1.0    features = 5      R2 = 0.917   RMSE = 63.356  Error_a1 = 0.281   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.917   RMSE = 63.193  Error_a1 = 0.250   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.923   RMSE = 61.117  Error_a1 = 0.250   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.928   RMSE = 59.081  Error_a1 = 0.281   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.911   RMSE = 65.734  Error_a1 = 0.281   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.869   RMSE = 68.161  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.848   RMSE = 73.593  Error_a1 = 0.375   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.882   RMSE = 64.854  Error_a1 = 0.312   Error_a2 = 0.688   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.874   RMSE = 66.779  Error_a1 = 0.344   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.882   RMSE = 64.622  Error_a1 = 0.375   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.883   RMSE = 64.347  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 680    feat_sel_thresh = 1.0    features = 5      R2 = 0.881   RMSE = 65.044  Error_a1 = 0.281   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.864   RMSE = 69.582  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.858   RMSE = 70.940  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 914    feat_sel_thresh = 1.0    features = 5      R2 = 0.849   RMSE = 73.153  Error_a1 = 0.375   Error_a2 = 0.688   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.558   RMSE = 140.575  Error_a1 = 0.188   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.556   RMSE = 140.877  Error_a1 = 0.156   Error_a2 = 0.438   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.590   RMSE = 135.517  Error_a1 = 0.219   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.602   RMSE = 133.502  Error_a1 = 0.188   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.563   RMSE = 139.789  Error_a1 = 0.219   Error_a2 = 0.438   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.589   RMSE = 135.577  Error_a1 = 0.219   Error_a2 = 0.531   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.554   RMSE = 141.252  Error_a1 = 0.188   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.574   RMSE = 138.093  Error_a1 = 0.156   Error_a2 = 0.469   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.567   RMSE = 139.202  Error_a1 = 0.094   Error_a2 = 0.438   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 914    feat_sel_thresh = 1.0    features = 5      R2 = 0.558   RMSE = 140.632  Error_a1 = 0.156   Error_a2 = 0.406   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.688   RMSE = 110.900  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.675   RMSE = 113.037  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.683   RMSE = 111.748  Error_a1 = 0.281   Error_a2 = 0.531   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.670   RMSE = 113.932  Error_a1 = 0.219   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 453    feat_sel_thresh = 1.0    features = 5      R2 = 0.699   RMSE = 108.895  Error_a1 = 0.219   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.701   RMSE = 108.480  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.684   RMSE = 111.471  Error_a1 = 0.219   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.685   RMSE = 111.339  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.698   RMSE = 109.091  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 914    feat_sel_thresh = 1.0    features = 5      R2 = 0.701   RMSE = 108.527  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.890   RMSE = 72.891  Error_a1 = 0.406   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.881   RMSE = 76.109  Error_a1 = 0.406   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.887   RMSE = 74.006  Error_a1 = 0.438   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.895   RMSE = 71.390  Error_a1 = 0.406   Error_a2 = 0.688   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.887   RMSE = 73.958  Error_a1 = 0.406   Error_a2 = 0.688   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.879   RMSE = 76.536  Error_a1 = 0.375   Error_a2 = 0.656   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.880   RMSE = 76.295  Error_a1 = 0.406   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.880   RMSE = 76.376  Error_a1 = 0.406   Error_a2 = 0.656   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.884   RMSE = 74.933  Error_a1 = 0.375   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.873   RMSE = 78.541  Error_a1 = 0.406   Error_a2 = 0.688   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.920   RMSE = 54.582  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.927   RMSE = 52.096  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 200    feat_sel_thresh = 1.0    features = 4      R2 = 0.919   RMSE = 54.733  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.924   RMSE = 53.230  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 453    feat_sel_thresh = 1.0    features = 5      R2 = 0.921   RMSE = 54.166  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.926   RMSE = 52.315  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.913   RMSE = 56.934  Error_a1 = 0.219   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.926   RMSE = 52.295  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.914   RMSE = 56.444  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.920   RMSE = 54.469  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.875   RMSE = 60.723  Error_a1 = 0.281   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.899   RMSE = 54.621  Error_a1 = 0.250   Error_a2 = 0.531   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.882   RMSE = 59.229  Error_a1 = 0.344   Error_a2 = 0.531   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.889   RMSE = 57.219  Error_a1 = 0.281   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 453    feat_sel_thresh = 1.0    features = 5      R2 = 0.899   RMSE = 54.573  Error_a1 = 0.312   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.895   RMSE = 55.634  Error_a1 = 0.312   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 680    feat_sel_thresh = 1.0    features = 5      R2 = 0.870   RMSE = 62.168  Error_a1 = 0.281   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.901   RMSE = 54.221  Error_a1 = 0.281   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.880   RMSE = 59.657  Error_a1 = 0.312   Error_a2 = 0.531   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 914    feat_sel_thresh = 1.0    features = 5      R2 = 0.906   RMSE = 52.776  Error_a1 = 0.281   Error_a2 = 0.500   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.678   RMSE = 130.496  Error_a1 = 0.344   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.660   RMSE = 134.013  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.660   RMSE = 134.050  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.656   RMSE = 134.798  Error_a1 = 0.344   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.676   RMSE = 130.882  Error_a1 = 0.375   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = PC           Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 563    feat_sel_thresh = 1.0    features = 5      R2 = 0.669   RMSE = 132.183  Error_a1 = 0.344   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.658   RMSE = 134.379  Error_a1 = 0.375   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.672   RMSE = 131.577  Error_a1 = 0.375   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.650   RMSE = 135.860  Error_a1 = 0.344   Error_a2 = 0.562   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.661   RMSE = 133.820  Error_a1 = 0.375   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
#     model random_state  sid kfold  ...        3N        3V       4N        4V
# 0      rf           20   22     5  ...        PC  0.593025  PC_Na2O  0.160704
# 1      rf           20  120     5  ...        PC  0.488123  PC_Na2O  0.183796
# 2      rf           20  200     5  ...       SCM  0.474207  PC_Na2O  0.178737
# 3      rf           20  420     5  ...        PC  0.527712  PC_Na2O  0.212528
# 4      rf           20  453     5  ...       SCM  0.501442  PC_Na2O  0.221131
# ..    ...          ...  ...   ...  ...       ...       ...      ...       ...
# 195    et          952  563     5  ...  SCM_SiO2  0.505419  PC_Na2O  0.186332
# 196    et          952  680     5  ...  SCM_SiO2  0.497485  PC_Na2O  0.237736
# 197    et          952  739     5  ...  SCM_SiO2  0.505918  PC_Na2O  0.216883
# 198    et          952  810     5  ...  SCM_SiO2  0.585294  PC_Na2O  0.206027
# 199    et          952  914     5  ...  SCM_SiO2  0.537159  PC_Na2O  0.197559
#
# [200 rows x 18 columns]
