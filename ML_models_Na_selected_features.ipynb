# %% [markdown]
# <a href="https://colab.research.google.com/github/cristhianaalbert/Poresolution_code/blob/Machine-learning-models/ML_models_Na_selected_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Initial setup

# %%
# !pip install requests==2.23.0 folium==0.2.1 imgaug==0.2.6 pycaret pandas shap 
from pycaret.utils import enable_colab
enable_colab()

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pycaret.utils import check_metric
from pycaret.regression import *

# %%
def count_alpha_error (a, alpha=0.1):

    '''Calculates the percentage of elements inside a +- alpha range around the true measured value of the ion;
     a = array with final predictions on unseen data;
     alpha = range of error
    '''
    error = a.Napredicted / a.Na                           #when we are dealing with log scale of ion, the analysis is still in absolute terms;
    count = error[((1-alpha) < error) & (error <(1+alpha))].size
    total = len(error)
    return count/total
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %% [markdown]
# Load dataset

# %%
from google.colab import files
uploaded = files.upload()
import io
#dataset = pd.read_csv(io.StringIO(uploaded['datasetMPKlogNa.csv'].decode('utf-8')))
dataset = pd.read_csv(io.StringIO(uploaded['database_Na_sel_1.csv'].decode('utf-8')),sep=',')

dataset.head()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#      <input type="file" id="files-ac36c05e-3bc5-4d8e-8972-560e1618c3f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac36c05e-3bc5-4d8e-8972-560e1618c3f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving database_Na_sel_1.csv to database_Na_sel_1.csv
#    Index    PC  SCM1  SCM1_type  SCM2  SCM2_type  PC_Na2O  PC_K2O  SCM1_SiO2  \
# 0      9  0.53  0.47          3  0.00          0     0.07    0.65      34.87
# 1     10  0.53  0.47          3  0.00          0     0.07    0.65      34.87
# 2     19  0.53  0.38          3  0.09          5     0.07    0.65      34.87
# 3     20  0.53  0.38          3  0.09          5     0.07    0.65      34.87
# 4     29  0.53  0.38          3  0.09          7     0.07    0.65      34.87
#
#    SCM1_Al2O3  SCM2_SiO2  SCM2_Al2O3     logNa    Na
# 0       11.62        0.0         0.0  1.754042  56.8
# 1       11.62        0.0         0.0  1.800717  63.2
# 2       11.62        2.0         0.8  1.745543  55.7
# 3       11.62        2.0         0.8  1.798029  62.8
# 4       11.62      100.0         0.0  1.775392  59.6

# %% [markdown]
# Visualize data

# %%
## combine these different collections into a list
mixproportion = [dataset.PC, dataset.SCM1, dataset.SCM2]
#mixproportion = [dataset.waterbinder]
sns.set_theme(style="white")

# Create a figure instance
fig = plt.figure()
# Create an axes instance
ax = fig.add_axes([0,0,1,1])
ax.set_ylabel('Mix proportion')
#ax.set_xlabel('Sample name') ['PC', 'SCM1', 'SCM2', 'w/b'] LEARN HOW TO SET THESE AXIS
# Create the boxplot
bp = ax.violinplot(mixproportion)
plt.show()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
## combine these different collections into a list
mixproportion = [10**dataset.logNa]
#mixproportion = [dataset.waterbinder]
sns.set_theme(style="white")

# Create a figure instance
fig = plt.figure()
# Create an axes instance
ax = fig.add_axes([0,0,1,1])
ax.set_ylabel('Mix proportion')
#ax.set_xlabel('Sample name') ['PC', 'SCM1', 'SCM2', 'w/b'] LEARN HOW TO SET THESE AXIS
# Create the boxplot
bp = ax.violinplot(mixproportion)
plt.show()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
fig, ax = plt.subplots()
sns.set_theme(style="white")
#sns.set_palette(sns.color_palette('Paired'))
mixproportion = [10**dataset.logNa]
sns.histplot(data=mixproportion, binwidth=0.01, log_scale=True,color='r', legend='Na')
#ax1.set_ylim(0, 30)
#plt.setp(ax, xticks=[10,100,1000])
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
display(dataset.shape)
dataset.describe()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# (210, 14)
#             Index          PC        SCM1   SCM1_type        SCM2   SCM2_type  \
# count  210.000000  210.000000  210.000000  210.000000  210.000000  210.000000
# mean   414.842857    0.823190    0.155524    1.233333    0.021571    0.366667
# std    267.207514    0.226039    0.191439    1.361758    0.080238    1.167270
# min      9.000000    0.200000    0.000000    0.000000    0.000000    0.000000
# 25%    177.250000    0.700000    0.000000    0.000000    0.000000    0.000000
# 50%    377.500000    0.940000    0.060000    1.000000    0.000000    0.000000
# 75%    606.000000    1.000000    0.300000    2.000000    0.000000    0.000000
# max    999.000000    1.000000    0.750000    5.000000    0.480000    7.000000
#
#           PC_Na2O      PC_K2O   SCM1_SiO2  SCM1_Al2O3   SCM2_SiO2  SCM2_Al2O3  \
# count  187.000000  183.000000  187.000000  192.000000  210.000000  210.000000
# mean     0.237594    0.619344   31.608342    6.385458    4.013810    1.104286
# std      0.182386    0.351067   37.973511   15.217129   15.564644    4.806239
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.130000    0.290000    0.000000    0.000000    0.000000    0.000000
# 50%      0.180000    0.540000    0.800000    0.000000    0.000000    0.000000
# 75%      0.410000    0.890000   49.015000    8.900000    0.000000    0.000000
# max      0.900000    1.230000   98.700000   85.530000  100.000000   26.900000
#
#             logNa          Na
# count  210.000000  210.000000
# mean     1.749258   94.036667
# std      0.522766   84.751890
# min      0.056766    1.100000
# 25%      1.595172   39.375000
# 50%      1.802634   63.500000
# 75%      2.130334  135.000000
# max      2.597695  396.000000

# %%
dataset.shape[1]
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# 14

# %%
SCM = dataset.SCM1 + dataset.SCM2
SCM_SiO2 = ( dataset.SCM1*dataset.SCM1_SiO2 + dataset.SCM2*dataset.SCM2_SiO2 ) / SCM
SCM_Al2O3 =( dataset.SCM1*dataset.SCM1_Al2O3 + dataset.SCM2*dataset.SCM2_Al2O3 ) / SCM
dataset.insert(dataset.shape[1],'SCM', SCM)
dataset.insert(dataset.shape[1],'SCM_SiO2', SCM_SiO2)
dataset.insert(dataset.shape[1],'SCM_Al2O3', SCM_Al2O3)
dataset.drop(['SCM1','SCM2','SCM1_type','SCM2_type','SCM1_SiO2','SCM1_Al2O3','SCM2_SiO2','SCM2_Al2O3'],axis=1,inplace=True)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %% [markdown]
# # Modeling

# %%
#defining initial parameters

model_list = ['rf','et']                        #models to be tested;
seed_list = [76,89,140,267,870]                       #seeds for separating data to train/test model and for final predictions; 
sid_list = [22,453,563,914]                         #seeds for session id on setup - I believe it defines how cross-validation groups are defined;
featsel_list = [1.0, 0.4, 0.3,0.2,0.15]         #feature_selection_threshold for setup - defines how many features will be considered in the model (train/test/prediction);
featsel_list = [1.0]         #feature_selection_threshold for setup - defines how many features will be considered in the model (train/test/prediction);
seed_list = [20, 76,89,140,267,310, 560, 771, 870, 952]                       #seeds for separating data to train/test model and for final predictions; 
sid_list = [22,120, 200, 420, 453, 563, 680, 739, 810, 914]                         #seeds for session id on setup - I believe it defines how cross-validation groups are defined;
kfold_list = [5]                            #numbers of folds for cross-validation - I didn't notice differences on the final results;


alpha1=0.1                                   #error range - used to evaluate +-10% error of prediction around the measured value;
alpha2=0.25                                  #error range - used to evaluate +-25% error of prediction around the measured value;
i=0                                          #initial index;

#tunemodel
tune_on = 1   # 1 to avoid tuning of hyperparameteres; 2 to allow tuning of hyperparameteres;
#These parameters are focused on decision tree methods;
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 20, stop = 100, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 10, num = 5)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
tune_params = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
                        

totalsystems = len(model_list)*len(seed_list)*len(sid_list)*len(featsel_list)*len(kfold_list)*tune_on   #total number of systems considering all variables; times 2 because we have tuned models
totalcolumns = 10                                                                                 #depends on the statistic variables stored on the array "summary" (modelname, ..., R2, RMSE, alpha, etc)
summary = np.zeros((totalsystems, totalcolumns),dtype=object)                                     #array summary mentioned above;

#REMEMBER TO ALTER DEPENDING ON THE SIZE OF DATASET (HOW MANY VARIABLES IT HAS)
estimativefeat = round(int(2*dataset.shape[1]))                        #depends on the number of features in dataset - needs to be a little bit bigger to account for categorical features that are transformed (one hot encoding method)
mostimpfeat = 4                           #number of most important features to be analysed; 15 or 10 seems a reasonable number;


mostimpfeat_value = np.ndarray(shape=(totalsystems, mostimpfeat+1),dtype=object)                      #arrays to store most important features properties; plus 1 is for indexing modelname
mostimpfeat_name = np.zeros(shape=(totalsystems, mostimpfeat+1),dtype=object)
mostimpfeat_test = np.zeros(shape=(totalsystems, 2*mostimpfeat+1),dtype=object)

feat_summary=[]

mostimpfeat_value_full = np.zeros(shape=(totalsystems, estimativefeat),dtype=float)               #arrays to store all features properties
mostimpfeat_name_full = np.zeros(shape=(totalsystems, estimativefeat),dtype=object)
mostimpfeat_full_summary = []


#numfeat = ['SCM2_Amorphous','C1_T','C2_Age_days','C2_T','Pressure_MPa']
ignfeat = ['Index',"Na"]
numfeat = ['waterbinder','aggregatesbinder',
           'PC','SCM1','SCM2','PC_CaO','PC_SiO2','PC_Al2O3', 'PC_Fe2O3', 'PC_SO3', 'PC_MgO', 'PC_Na2O', 'PC_K2O', 
           'PC_TiO2', 'PC_P2O5', 'PC_MnO', 'PC_CO2','PC_LOI', 'PC_Amorphous', 'PC_C3S', 'PC_C2S', 'PC_C3A', 'PC_C4AF','PC_Blaine','PC_BET',
           'SCM1_CaO',	'SCM1_SiO2',	'SCM1_Al2O3',	'SCM1_Fe2O3',	'SCM1_SO3',	'SCM1_MgO',	'SCM1_Na2O',	'SCM1_K2O',	
           'SCM1_TiO2',	'SCM1_P2O5',	'SCM1_MnO',	'SCM1_CO2',	'SCM1_LOI','SCM1_Amorphous','SCM1_Blaine','SCM1_BET',
           'SCM2_CaO',	'SCM2_SiO2',	'SCM2_Al2O3',	'SCM2_Fe2O3',	'SCM2_SO3',	'SCM2_MgO',	'SCM2_Na2O',	'SCM2_K2O',	
           'SCM2_TiO2',	'SCM2_P2O5',	'SCM2_MnO',	'SCM2_CO2',	'SCM2_LOI','SCM2_Amorphous','SCM2_Blaine','SCM2_BET',
           'C1_Age_days','C1_RH','C1_T','C2_Age_days','C2_RH','C2_T','Final_age_days','Pressure_MPa']

numfeat = ['PC','SCM','PC_Na2O','PC_K2O','SCM_SiO2','SCM_Al2O3']


for modelname in model_list:                                #running for different models at same loop;
  for p in range(tune_on):                                                                                          #creating a normal and tuned version of the model  %TO AVOID HAVING TUNED MODELS, JUST PUT THE RANGE TO 1 INSTEAD OF 2

    for seed in seed_list:                                                                                      #running for different initial seeds for ramdom state - separation of data to train/test model and for final predictions;
      data = dataset.sample(frac=0.85, random_state=seed)
      data_unseen = dataset.drop(data.index)
      data.reset_index(drop=True, inplace=True)
      data_unseen.reset_index(drop=True, inplace=True)

      for sid in sid_list:                                                                                      #running for different seeds for session id on setup - I believe it defines how cross-validation groups are defined;
        for featsel in featsel_list:                                                                            #running different feature_selection_threshold for setup - defines how many features will be considered in the model (train/test/prediction)

          exp_ps = setup(data = data, target = 'logNa', session_id=sid, normalize = True, 
                        combine_rare_levels = True, rare_level_threshold = 0.05,
                        remove_outliers = True, log_experiment = True, experiment_name = 'poresolution',
                        numeric_features = numfeat, fold=5, ignore_features = ignfeat,
                        feature_selection = True, silent=True, verbose=False)

          for kfold in kfold_list:                          #running for different numbers of folds for cross-validation - I didn't notice differences on the final results;
            #model = create_model(modelname,fold=kfold, n_estimators=80,max_depth=10, verbose=False)
            model = create_model(modelname,n_estimators=80,max_depth=8,fold=kfold,verbose=False)


            if p == 0:                                      #normal model
              model = model           
              modelnameb = modelname

            if p == 1:                                      #tuned model
              model = tune_model(model,fold=kfold, optimize="RMSE", verbose=False)
              modelnameb = 'tuned_'+str(modelname)
            
            aaa=get_logs()

            final_model = finalize_model(model)
            unseen_predictions = predict_model(final_model, data=data_unseen, round=None)
            #test_predictions = predict_model(final_model, data=data_testprediction, round=None)

            #checking accuracy of predictions on unseen data - R2, RMSE, fraction of predictions within alpha error range;
            a = unseen_predictions
            alinear = pd.DataFrame([np.array(10**a.logNa), np.array(10**a.Label)]).T
            alinear.columns=["Na","Napredicted"]            
            R2 = check_metric(alinear.Na, alinear.Napredicted, 'R2' )     
            RMSE = check_metric(alinear.Na, alinear.Napredicted, 'RMSE' )
            erroralpha1 = count_alpha_error(alinear, alpha1)
            erroralpha2 = count_alpha_error(alinear, alpha2)

            nfeat = get_config('X_train').shape[1]           #number of features considered by model - depends on feature_selection_threshold;               

            summary[i,:] = ([modelnameb, seed, sid, kfold, featsel,nfeat, R2, RMSE, erroralpha1, erroralpha2])     #storing all these metrics for each system;


            featimp = pd.DataFrame({'Feature': get_config('X_train').columns, 'Value' : abs(final_model.feature_importances_)})    #getting the feature importance scores for all systems;
            featimpsort = featimp.sort_values(by='Value', ascending=False)[:mostimpfeat]                                           #organizing feature importance scores in descending order of importance;
            
            feat1 = np.array(featimpsort)[0,0]            #1st to 5th most important feature -> to be displayed during evaluations -> important to checks during runs;
            feat2 = np.array(featimpsort)[1,0]
            feat3 = np.array(featimpsort)[2,0]
            feat4 = np.array(featimpsort)[3,0]
            #feat5 = np.array(featimpsort)[4,0]

            mostimpfeat_name[i][0] = modelnameb                                                      #indexing the modelnameb to later identify where did the features get the most contribution
            mostimpfeat_value[i][0] = modelnameb                                                     #indexing the modelnameb to later identify where did the features get the most contribution
            for j in range(mostimpfeat):                                                             #arranging names and values of most important features in two arrays; 
              mostimpfeat_name[i][j+1] = np.array(featimpsort)[j,0]                                  #feature name
              mostimpfeat_value[i][j+1] = np.array(featimpsort)[j,1]/np.array(featimpsort)[0,1]      #feature importance value normalized in relation to most important feature;

            mostimpfeat_test[i][0] = modelnameb                                                      #indexing the modelnameb to later identify where did the features get the most contribution
            for j in range(mostimpfeat):                                                             #arranging names and values of most important features in one array; -> best method;
              mostimpfeat_test[i][2*j+1] = np.array(featimpsort)[j,0]                                #feature name
              mostimpfeat_test[i][2*j+2] = np.array(featimpsort)[j,1]/np.array(featimpsort)[0,1]     #feature importance value normalized in relation to most important feature;



            for k in range(nfeat):                                                                   #arranging names and values of all features in two arrays; 
              mostimpfeat_name_full[i][k] = np.array(featimp)[k,0]                                   #feature name
              mostimpfeat_value_full[i][k] = np.array(featimp)[k,1]/np.array(featimpsort)[0,1]       #feature importance value normalized in relation to most important feature;

            for ida, system in enumerate(mostimpfeat_name_full):          #arranging names and values of most important features in one array; -> best method;
              for idb, name in enumerate(system):
                value = mostimpfeat_value_full[ida][idb]
                mostimpfeat_full_summary.append([ida,idb,name,value])      

            i=i+1                                                         #finishing round and going to next one; increasing index number accordingly;

        #print('random_state=',seed,'  session_id=',sid,'  kfold=',kfold,'  R2=', R2, '  RMSE=', RMSE)
            print('''model = {: <10}  random_state = {: <5}  sid = {: <5}  feat_sel_thresh = {: <5}  features = {:<5}  R2 = {:.3f}   RMSE = {:.3f}  Error_a1 = {:.3f}   Error_a2 = {:.3f}   Feat1 = {: <10}   Feat2 = {: <10}   Feat3 = {: <10}     Feat4 = {: <10}   '''
                    .format(modelnameb,seed,sid,featsel, nfeat, R2, RMSE,erroralpha1, erroralpha2, feat1, feat2, feat3, feat4))


pd.DataFrame(mostimpfeat_test).to_csv('mostimpfeat_test.csv',index=False)

table_summary = pd.DataFrame(summary)                 #creating table of statistics for all systems;
table_summary.columns = ['model','random_state','sid','kfold','feat_sel_thresh','features','R2','RMSE','Error_alpha_0.1','Error_alpha_0.25']


columnname = []                                       #creating column names for most important features - we might change the number of selected features 
for i in range(mostimpfeat):
  columnname.append(str(i+1)+'N')
  columnname.append(str(i+1)+'V')

table_mostimpfeat = pd.DataFrame(mostimpfeat_test[:,1:])    #creating table of most important features with their name and value/score;
table_mostimpfeat.columns = columnname

finaltable = pd.concat([table_summary, table_mostimpfeat], axis=1, join='inner')   #combining statistics and most imp features in only one table; it helps on converting it to only one csv file later.
finaltable.to_csv('finaltable.csv')
display(finaltable)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# model = rf          random_state = 20     sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.769   RMSE = 48.463  Error_a1 = 0.375   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 20     sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.774   RMSE = 48.027  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.765   RMSE = 48.974  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.774   RMSE = 47.995  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.775   RMSE = 47.827  Error_a1 = 0.375   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.763   RMSE = 49.175  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.751   RMSE = 50.352  Error_a1 = 0.406   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 20     sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.746   RMSE = 50.905  Error_a1 = 0.344   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 20     sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.754   RMSE = 50.059  Error_a1 = 0.375   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 20     sid = 914    feat_sel_thresh = 1.0    features = 5      R2 = 0.750   RMSE = 50.501  Error_a1 = 0.312   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 76     sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.716   RMSE = 43.772  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 76     sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.744   RMSE = 41.572  Error_a1 = 0.250   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 76     sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.727   RMSE = 42.955  Error_a1 = 0.344   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 76     sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.738   RMSE = 42.038  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 76     sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.761   RMSE = 40.178  Error_a1 = 0.312   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 76     sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.734   RMSE = 42.393  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 76     sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.726   RMSE = 43.018  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 76     sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.737   RMSE = 42.160  Error_a1 = 0.344   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 76     sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.723   RMSE = 43.222  Error_a1 = 0.344   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 76     sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.727   RMSE = 42.946  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 89     sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.902   RMSE = 24.808  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 89     sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.913   RMSE = 23.311  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 89     sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.896   RMSE = 25.544  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 89     sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.901   RMSE = 24.914  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 89     sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.878   RMSE = 27.631  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 89     sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.892   RMSE = 26.054  Error_a1 = 0.281   Error_a2 = 0.469   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.902   RMSE = 24.753  Error_a1 = 0.219   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 89     sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.897   RMSE = 25.335  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.886   RMSE = 26.734  Error_a1 = 0.281   Error_a2 = 0.469   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 89     sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.893   RMSE = 25.937  Error_a1 = 0.281   Error_a2 = 0.500   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 140    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.524   RMSE = 42.223  Error_a1 = 0.375   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 140    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.533   RMSE = 41.815  Error_a1 = 0.344   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 140    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.473   RMSE = 44.424  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 140    sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.501   RMSE = 43.233  Error_a1 = 0.250   Error_a2 = 0.625   Feat1 = PC_K2O       Feat2 = SCM_SiO2     Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 140    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.527   RMSE = 42.103  Error_a1 = 0.344   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 140    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.546   RMSE = 41.250  Error_a1 = 0.344   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 140    sid = 680    feat_sel_thresh = 1.0    features = 5      R2 = 0.536   RMSE = 41.673  Error_a1 = 0.344   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 140    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.520   RMSE = 42.401  Error_a1 = 0.344   Error_a2 = 0.531   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 140    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.514   RMSE = 42.646  Error_a1 = 0.344   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 140    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.499   RMSE = 43.335  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 267    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.822   RMSE = 36.037  Error_a1 = 0.281   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 267    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.788   RMSE = 39.338  Error_a1 = 0.250   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.792   RMSE = 38.917  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.740   RMSE = 43.527  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 453    feat_sel_thresh = 1.0    features = 5      R2 = 0.767   RMSE = 41.225  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 267    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.775   RMSE = 40.475  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.776   RMSE = 40.394  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.810   RMSE = 37.234  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 267    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.808   RMSE = 37.362  Error_a1 = 0.250   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 267    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.814   RMSE = 36.847  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.873   RMSE = 31.000  Error_a1 = 0.281   Error_a2 = 0.719   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.851   RMSE = 33.539  Error_a1 = 0.281   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 310    sid = 200    feat_sel_thresh = 1.0    features = 4      R2 = 0.853   RMSE = 33.334  Error_a1 = 0.312   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 310    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.875   RMSE = 30.777  Error_a1 = 0.219   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 310    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.874   RMSE = 30.881  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 310    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.860   RMSE = 32.580  Error_a1 = 0.219   Error_a2 = 0.562   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.862   RMSE = 32.323  Error_a1 = 0.312   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 310    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.843   RMSE = 34.431  Error_a1 = 0.375   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.876   RMSE = 30.594  Error_a1 = 0.281   Error_a2 = 0.719   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 310    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.851   RMSE = 33.503  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 560    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.597   RMSE = 42.126  Error_a1 = 0.438   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 560    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.662   RMSE = 38.564  Error_a1 = 0.406   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 560    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.625   RMSE = 40.641  Error_a1 = 0.438   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 560    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.644   RMSE = 39.604  Error_a1 = 0.438   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 560    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.664   RMSE = 38.463  Error_a1 = 0.438   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 560    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.672   RMSE = 38.034  Error_a1 = 0.375   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 560    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.635   RMSE = 40.074  Error_a1 = 0.469   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 560    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.663   RMSE = 38.523  Error_a1 = 0.469   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 560    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.657   RMSE = 38.843  Error_a1 = 0.375   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 560    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.690   RMSE = 36.947  Error_a1 = 0.406   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 771    sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.892   RMSE = 30.214  Error_a1 = 0.438   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.898   RMSE = 29.352  Error_a1 = 0.375   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.892   RMSE = 30.241  Error_a1 = 0.375   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.898   RMSE = 29.379  Error_a1 = 0.344   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.899   RMSE = 29.249  Error_a1 = 0.375   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.884   RMSE = 31.364  Error_a1 = 0.406   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = rf          random_state = 771    sid = 680    feat_sel_thresh = 1.0    features = 5      R2 = 0.896   RMSE = 29.718  Error_a1 = 0.406   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 771    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.904   RMSE = 28.428  Error_a1 = 0.406   Error_a2 = 0.750   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 771    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.904   RMSE = 28.517  Error_a1 = 0.375   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 771    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.893   RMSE = 30.104  Error_a1 = 0.375   Error_a2 = 0.750   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = SCM            Feat4 = PC_Na2O
# model = rf          random_state = 870    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.856   RMSE = 33.818  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 870    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.836   RMSE = 36.117  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 870    sid = 200    feat_sel_thresh = 1.0    features = 4      R2 = 0.853   RMSE = 34.255  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 870    sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.869   RMSE = 32.346  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 870    sid = 453    feat_sel_thresh = 1.0    features = 5      R2 = 0.848   RMSE = 34.758  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 870    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.815   RMSE = 38.362  Error_a1 = 0.281   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 870    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.846   RMSE = 35.028  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 870    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.862   RMSE = 33.120  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 870    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.825   RMSE = 37.303  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 870    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.832   RMSE = 36.570  Error_a1 = 0.344   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 952    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.680   RMSE = 43.287  Error_a1 = 0.375   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 952    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.641   RMSE = 45.820  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 952    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.649   RMSE = 45.319  Error_a1 = 0.312   Error_a2 = 0.500   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 952    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.653   RMSE = 45.045  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 952    sid = 453    feat_sel_thresh = 1.0    features = 5      R2 = 0.600   RMSE = 48.394  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 952    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.671   RMSE = 43.830  Error_a1 = 0.281   Error_a2 = 0.531   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = rf          random_state = 952    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.641   RMSE = 45.829  Error_a1 = 0.344   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 952    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.613   RMSE = 47.557  Error_a1 = 0.281   Error_a2 = 0.438   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 952    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.630   RMSE = 46.492  Error_a1 = 0.312   Error_a2 = 0.500   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = SCM
# model = rf          random_state = 952    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.633   RMSE = 46.337  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC_Na2O        Feat4 = PC
# model = et          random_state = 20     sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.694   RMSE = 55.876  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = SCM          Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.704   RMSE = 54.887  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.718   RMSE = 53.569  Error_a1 = 0.219   Error_a2 = 0.625   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.714   RMSE = 54.008  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.710   RMSE = 54.341  Error_a1 = 0.250   Error_a2 = 0.656   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.713   RMSE = 54.085  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.719   RMSE = 53.540  Error_a1 = 0.250   Error_a2 = 0.656   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.716   RMSE = 53.790  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.697   RMSE = 55.556  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 20     sid = 914    feat_sel_thresh = 1.0    features = 5      R2 = 0.693   RMSE = 55.902  Error_a1 = 0.281   Error_a2 = 0.531   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.688   RMSE = 45.875  Error_a1 = 0.219   Error_a2 = 0.531   Feat1 = SCM_SiO2     Feat2 = PC           Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.662   RMSE = 47.765  Error_a1 = 0.219   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.684   RMSE = 46.200  Error_a1 = 0.250   Error_a2 = 0.562   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.706   RMSE = 44.569  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = SCM          Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.702   RMSE = 44.881  Error_a1 = 0.281   Error_a2 = 0.531   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.721   RMSE = 43.423  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC           Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.699   RMSE = 45.096  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = PC_K2O       Feat2 = SCM          Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.665   RMSE = 47.568  Error_a1 = 0.219   Error_a2 = 0.562   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.687   RMSE = 45.987  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = et          random_state = 76     sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.686   RMSE = 46.072  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC_K2O       Feat3 = PC             Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.893   RMSE = 25.874  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.882   RMSE = 27.186  Error_a1 = 0.219   Error_a2 = 0.562   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.901   RMSE = 24.880  Error_a1 = 0.188   Error_a2 = 0.531   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.891   RMSE = 26.092  Error_a1 = 0.281   Error_a2 = 0.531   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.896   RMSE = 25.553  Error_a1 = 0.250   Error_a2 = 0.531   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.897   RMSE = 25.384  Error_a1 = 0.188   Error_a2 = 0.531   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.895   RMSE = 25.589  Error_a1 = 0.219   Error_a2 = 0.531   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.888   RMSE = 26.422  Error_a1 = 0.250   Error_a2 = 0.500   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.891   RMSE = 26.066  Error_a1 = 0.281   Error_a2 = 0.500   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 89     sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.899   RMSE = 25.162  Error_a1 = 0.250   Error_a2 = 0.500   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.482   RMSE = 44.042  Error_a1 = 0.344   Error_a2 = 0.625   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.478   RMSE = 44.236  Error_a1 = 0.344   Error_a2 = 0.625   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.462   RMSE = 44.879  Error_a1 = 0.344   Error_a2 = 0.625   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.483   RMSE = 43.997  Error_a1 = 0.375   Error_a2 = 0.656   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.476   RMSE = 44.316  Error_a1 = 0.281   Error_a2 = 0.625   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.466   RMSE = 44.719  Error_a1 = 0.312   Error_a2 = 0.688   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 680    feat_sel_thresh = 1.0    features = 5      R2 = 0.497   RMSE = 43.403  Error_a1 = 0.281   Error_a2 = 0.625   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.485   RMSE = 43.922  Error_a1 = 0.281   Error_a2 = 0.625   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.473   RMSE = 44.441  Error_a1 = 0.375   Error_a2 = 0.625   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 140    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.457   RMSE = 45.122  Error_a1 = 0.344   Error_a2 = 0.656   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.771   RMSE = 40.823  Error_a1 = 0.344   Error_a2 = 0.688   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.787   RMSE = 39.416  Error_a1 = 0.281   Error_a2 = 0.688   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.742   RMSE = 43.342  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.773   RMSE = 40.715  Error_a1 = 0.312   Error_a2 = 0.688   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 453    feat_sel_thresh = 1.0    features = 5      R2 = 0.780   RMSE = 40.030  Error_a1 = 0.281   Error_a2 = 0.688   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.722   RMSE = 45.055  Error_a1 = 0.344   Error_a2 = 0.688   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.805   RMSE = 37.677  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.785   RMSE = 39.621  Error_a1 = 0.312   Error_a2 = 0.719   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 810    feat_sel_thresh = 1.0    features = 5      R2 = 0.736   RMSE = 43.836  Error_a1 = 0.344   Error_a2 = 0.688   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 267    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.765   RMSE = 41.391  Error_a1 = 0.281   Error_a2 = 0.656   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.787   RMSE = 40.126  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.765   RMSE = 42.166  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC           Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 200    feat_sel_thresh = 1.0    features = 4      R2 = 0.774   RMSE = 41.275  Error_a1 = 0.281   Error_a2 = 0.531   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.773   RMSE = 41.440  Error_a1 = 0.250   Error_a2 = 0.531   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.772   RMSE = 41.494  Error_a1 = 0.312   Error_a2 = 0.531   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.785   RMSE = 40.341  Error_a1 = 0.281   Error_a2 = 0.688   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.793   RMSE = 39.559  Error_a1 = 0.219   Error_a2 = 0.562   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.795   RMSE = 39.358  Error_a1 = 0.250   Error_a2 = 0.531   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.781   RMSE = 40.645  Error_a1 = 0.312   Error_a2 = 0.531   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 310    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.787   RMSE = 40.142  Error_a1 = 0.312   Error_a2 = 0.531   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.724   RMSE = 34.878  Error_a1 = 0.500   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = PC           Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 120    feat_sel_thresh = 1.0    features = 4      R2 = 0.731   RMSE = 34.408  Error_a1 = 0.500   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = SCM          Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.710   RMSE = 35.736  Error_a1 = 0.594   Error_a2 = 0.688   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.713   RMSE = 35.559  Error_a1 = 0.469   Error_a2 = 0.688   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.741   RMSE = 33.779  Error_a1 = 0.531   Error_a2 = 0.688   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.693   RMSE = 36.758  Error_a1 = 0.531   Error_a2 = 0.656   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.684   RMSE = 37.297  Error_a1 = 0.594   Error_a2 = 0.688   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.719   RMSE = 35.204  Error_a1 = 0.500   Error_a2 = 0.719   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.709   RMSE = 35.819  Error_a1 = 0.500   Error_a2 = 0.688   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 560    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.719   RMSE = 35.184  Error_a1 = 0.531   Error_a2 = 0.688   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 22     feat_sel_thresh = 1.0    features = 4      R2 = 0.817   RMSE = 39.299  Error_a1 = 0.344   Error_a2 = 0.688   Feat1 = SCM_SiO2     Feat2 = SCM          Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.830   RMSE = 37.904  Error_a1 = 0.344   Error_a2 = 0.656   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.820   RMSE = 38.985  Error_a1 = 0.344   Error_a2 = 0.656   Feat1 = SCM_SiO2     Feat2 = SCM          Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.813   RMSE = 39.750  Error_a1 = 0.344   Error_a2 = 0.625   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 453    feat_sel_thresh = 1.0    features = 4      R2 = 0.809   RMSE = 40.187  Error_a1 = 0.344   Error_a2 = 0.656   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.807   RMSE = 40.420  Error_a1 = 0.375   Error_a2 = 0.656   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 680    feat_sel_thresh = 1.0    features = 5      R2 = 0.825   RMSE = 38.457  Error_a1 = 0.344   Error_a2 = 0.656   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.817   RMSE = 39.347  Error_a1 = 0.375   Error_a2 = 0.656   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.813   RMSE = 39.799  Error_a1 = 0.375   Error_a2 = 0.656   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 771    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.805   RMSE = 40.601  Error_a1 = 0.312   Error_a2 = 0.656   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.869   RMSE = 32.269  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.874   RMSE = 31.646  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 200    feat_sel_thresh = 1.0    features = 4      R2 = 0.881   RMSE = 30.732  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC           Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 420    feat_sel_thresh = 1.0    features = 4      R2 = 0.875   RMSE = 31.594  Error_a1 = 0.281   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = SCM          Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 453    feat_sel_thresh = 1.0    features = 5      R2 = 0.870   RMSE = 32.193  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.878   RMSE = 31.172  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.881   RMSE = 30.783  Error_a1 = 0.312   Error_a2 = 0.594   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 739    feat_sel_thresh = 1.0    features = 4      R2 = 0.880   RMSE = 30.946  Error_a1 = 0.250   Error_a2 = 0.656   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.878   RMSE = 31.211  Error_a1 = 0.312   Error_a2 = 0.625   Feat1 = SCM_SiO2     Feat2 = SCM          Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 870    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.875   RMSE = 31.515  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = PC           Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 22     feat_sel_thresh = 1.0    features = 5      R2 = 0.591   RMSE = 48.882  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC           Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 120    feat_sel_thresh = 1.0    features = 5      R2 = 0.598   RMSE = 48.507  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC           Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 200    feat_sel_thresh = 1.0    features = 5      R2 = 0.552   RMSE = 51.202  Error_a1 = 0.312   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = SCM          Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 420    feat_sel_thresh = 1.0    features = 5      R2 = 0.558   RMSE = 50.846  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = PC           Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 453    feat_sel_thresh = 1.0    features = 5      R2 = 0.601   RMSE = 48.298  Error_a1 = 0.219   Error_a2 = 0.562   Feat1 = SCM_SiO2     Feat2 = PC           Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 563    feat_sel_thresh = 1.0    features = 4      R2 = 0.609   RMSE = 47.806  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC           Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 680    feat_sel_thresh = 1.0    features = 4      R2 = 0.609   RMSE = 47.822  Error_a1 = 0.281   Error_a2 = 0.562   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 739    feat_sel_thresh = 1.0    features = 5      R2 = 0.597   RMSE = 48.573  Error_a1 = 0.250   Error_a2 = 0.531   Feat1 = SCM          Feat2 = PC_K2O       Feat3 = SCM_SiO2       Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 810    feat_sel_thresh = 1.0    features = 4      R2 = 0.586   RMSE = 49.238  Error_a1 = 0.281   Error_a2 = 0.594   Feat1 = SCM          Feat2 = SCM_SiO2     Feat3 = PC_K2O         Feat4 = PC_Na2O
# model = et          random_state = 952    sid = 914    feat_sel_thresh = 1.0    features = 4      R2 = 0.614   RMSE = 47.501  Error_a1 = 0.250   Error_a2 = 0.594   Feat1 = SCM_SiO2     Feat2 = PC           Feat3 = PC_K2O         Feat4 = PC_Na2O
#     model random_state  sid kfold  ...        3N        3V       4N        4V
# 0      rf           20   22     5  ...   PC_Na2O   0.34799      SCM  0.327257
# 1      rf           20  120     5  ...       SCM  0.477045  PC_Na2O   0.35782
# 2      rf           20  200     5  ...       SCM  0.379197  PC_Na2O   0.35295
# 3      rf           20  420     5  ...  SCM_SiO2  0.681825  PC_Na2O  0.521368
# 4      rf           20  453     5  ...       SCM  0.371238  PC_Na2O  0.350106
# ..    ...          ...  ...   ...  ...       ...       ...      ...       ...
# 195    et          952  563     5  ...    PC_K2O   0.83623  PC_Na2O  0.592979
# 196    et          952  680     5  ...    PC_K2O  0.899147  PC_Na2O  0.550181
# 197    et          952  739     5  ...  SCM_SiO2  0.834545  PC_Na2O  0.567144
# 198    et          952  810     5  ...    PC_K2O  0.897332  PC_Na2O  0.602684
# 199    et          952  914     5  ...    PC_K2O  0.785051  PC_Na2O  0.626503
#
# [200 rows x 18 columns]
